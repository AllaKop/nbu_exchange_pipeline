# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="../.env")
# Out:
# True

# %%
from snowflake.snowpark import Session

connection_parameters = {
    "account": "YUJMLNP-YOB51920",
    "user": os.environ["SNOWFLAKE_USER"],
    "password": os.environ["SNOWFLAKE_PASSWORD"],
    "role": os.environ.get("SNOWFLAKE_ROLE"),
    "warehouse": "COMPUTE_WH",
    "database": "NBU_EXCHANGE",
    "schema": "SILVER"
}

session = Session.builder.configs(connection_parameters).create()

# %%
exchange_rate_extracted_df = session.table("nbu_exchange.silver.exchange_rate_extracted")
exchange_rate_extracted_df.show(5)
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"CALCULATION_DATE"  |"CURRENCY_CODE"  |"CURRENCY_NAME"  |"EXCHANGE_DATE"  |"GROUP_NUMBER"  |"R030_CODE"  |"RATE"    |"RATE_PER_UNIT"  |"SPECIAL_CONDITIONS"  |"CURRENCY_NAME_UA"      |"UNITS"  |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |                    |USD              |NULL             |30.06.1996       |1               |1            |178600.0  |178600.0         |NULL                  |Долар США               |1        |
# |                    |LTL              |NULL             |30.06.1996       |1               |954          |44650.0   |44650.0          |NULL                  |Литовський літ          |1        |
# |                    |NLG              |NULL             |30.06.1996       |1               |5            |104650.0  |104650.0         |NULL                  |Нiдерландський гульден  |1        |
# |                    |CHF              |NULL             |30.06.1996       |1               |6            |142750.0  |142750.0         |NULL                  |Швейцарський франк      |1        |
# |                    |SEK              |NULL             |30.06.1996       |1               |7            |26870.0   |26870.0          |NULL                  |Шведська крона          |1        |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -- Need to do:
# -- 0. deduplicate - after cleaning and mapping!
# -- 3. currency_code upper case maybe
# -- 4. currency_name has nulls (IS null), map
# -- 6. group_number (1,2,3) find what's the meaning, map with names
# -- 7. r030_code - 150 r030 count, 109 currency count?
# -- 8. r030_code - 3d group is precious metals, 2nd and 1st the same currency?
# -- 9. rate - seems ok
# -- 10. rate_per_unit - seems ok
# -- 11. special_conditions - seems ok
# -- Special=null/Y/N - sign of the conditions for calculating the hryvnia to US dollar
# -- exchange rate: null - for records for days when the sign was not determined and for
# -- valcode≠usd, Y - under special conditions, N - under normal conditions;
# -- 12. currency_name_ua - seems ok, can add additional column with countries
# -- 13. units - seems ok
# -- add collumn if records valid
#
# -- Create a new table for cleaned and transformed data

# %%
from snowflake.snowpark.functions import col, when, trim, to_date, lit, sql_expr, count

# %%
# Cast date columns to date type and handle null or empty values for calculation_date

exchange_rate_extracted_df = exchange_rate_extracted_df \
    .with_column(
        "calculation_date",
        when(
            (trim(col("calculation_date")) == lit('')) | col("calculation_date").is_null(),
            to_date(lit("01.01.1900"), "DD.MM.YYYY")
        ).otherwise(
            to_date(trim(col("calculation_date")), "DD.MM.YYYY")
        )
    ) \
    .with_column(
        "exchange_date",
        to_date(col("exchange_date"), "DD.MM.YYYY")
    )

# %%
exchange_rate_extracted_df \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .order_by('currency_name_ua') \
    .show(250)
# Out:
# --------------------------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"              |"CURRENCY_NAME_UA"                  |
# --------------------------------------------------------------------------------------
# |DEM              |NULL                         |Hімецькі маpки                      |
# |EUR              |NULL                         |Євро                                |
# |EUR              |Euro                         |Євро                                |
# |EGP              |Egyptian Pound               |Єгипетський фунт                    |
# |EGP              |NULL                         |Єгипетський фунт                    |
# |JPY              |Yen                          |Єна                                 |
# |JPY              |NULL                         |Єна                                 |
# |INR              |Indian Rupee                 |Індійська рупія                     |
# |INR              |NULL                         |Індійська рупія                     |
# |IQD              |Iraqi Dinar                  |Іракський динар                     |
# |IQD              |NULL                         |Іракський динар                     |
# |IRR              |NULL                         |Іранський ріал                      |
# |IRR              |Iranian Rial                 |Іранський ріал                      |
# |IEP              |NULL                         |Ірландський фунт                    |
# |IEP              |NULL                         |Ірландські фунти                    |
# |ISK              |NULL                         |Ісландська крона                    |
# |ISK              |NULL                         |Ісландські крони                    |
# |ESP              |NULL                         |Іспанскі пессети                    |
# |ESP              |NULL                         |Іспанська песета                    |
# |ITL              |NULL                         |Італійська ліра                     |
# |ITL              |NULL                         |Італійські ліpи                     |
# |AUD              |NULL                         |Австралійський долар                |
# |AUD              |Australian Dollar            |Австралійський долар                |
# |ATS              |NULL                         |Австрійський шилінг                 |
# |AZN              |NULL                         |Азербайджанський манат              |
# |AZM              |NULL                         |Азербайджанський манат              |
# |AZN              |Azerbaijan Manat             |Азербайджанський манат              |
# |DZD              |Algerian Dinar               |Алжирський динар                    |
# |DZD              |NULL                         |Алжирський динар                    |
# |GBP              |NULL                         |Англійський фунт стерлінгів         |
# |BYB              |NULL                         |Бiлоруський рубль                   |
# |BYR              |NULL                         |Бiлоруський рубль                   |
# |BYN              |NULL                         |Бiлоруський рубль                   |
# |BYN              |Belarusian Ruble             |Бiлоруський рубль                   |
# |THB              |Baht                         |Бат                                 |
# |THB              |NULL                         |Бат                                 |
# |BEF              |NULL                         |Бельгійський франк                  |
# |BGN              |Bulgarian Lev                |Болгарський лев                     |
# |BGN              |NULL                         |Болгарський лев                     |
# |BGL              |NULL                         |Болгарські леви                     |
# |BRL              |NULL                         |Бразильський реал                   |
# |BRL              |Brazilian Real               |Бразильський реал                   |
# |BYN              |Belarusian Ruble             |Білоруський рубль                   |
# |AMD              |NULL                         |Вiрменський драм                    |
# |WDR              |NULL                         |Вiрменський драм                    |
# |KRW              |NULL                         |Вон (Республіка Корея)              |
# |KRW              |NULL                         |Вона                                |
# |KRW              |Won                          |Вона                                |
# |AMD              |Armenian Dram                |Вірменський драм                    |
# |GHS              |Ghana Cedi                   |Ганське седі                        |
# |GHS              |NULL                         |Ганських седі                       |
# |NLG              |NULL                         |Голандські гульдени                 |
# |HKD              |NULL                         |Гонконгівський долар                |
# |HKD              |Hong Kong Dollar             |Гонконгівський долар                |
# |GRD              |NULL                         |Грецька драхма                      |
# |GRD              |NULL                         |Грецькі драхми                      |
# |GEK              |NULL                         |Грузинський купон                   |
# |GEL              |NULL                         |Грузинські ларі                     |
# |DKK              |NULL                         |Данська крона                       |
# |DKK              |Danish Krone                 |Данська крона                       |
# |HRD              |NULL                         |Динар                               |
# |AED              |NULL                         |Дирхам ОАЕ                          |
# |AED              |UAE Dirham                   |Дирхам ОАЕ                          |
# |HKD              |NULL                         |Долар Гонконгу                      |
# |USD              |NULL                         |Долар США                           |
# |USD              |US Dollar                    |Долар США                           |
# |USD              |United States dollar         |Долар США                           |
# |___              |NULL                         |Долари США по розр. з Індією        |
# |DOP              |Dominican Peso               |Домініканське песо                  |
# |VND              |NULL                         |Донг                                |
# |VND              |Dong                         |Донг                                |
# |GRD              |NULL                         |Драхма (Греція)                     |
# |XEU              |NULL                         |ЕКЮ                                 |
# |ECS              |NULL                         |Еквадорський сукре                  |
# |XEU              |NULL                         |Екю                                 |
# |EEK              |NULL                         |Естонська крона                     |
# |PLN              |NULL                         |Злотий                              |
# |PLN              |Zloty                        |Злотий                              |
# |PLZ              |NULL                         |Злотий                              |
# |XAU              |Gold                         |Золото                              |
# |XAU              |NULL                         |Золото                              |
# |XOF              |NULL                         |КФА франк BCEAO                     |
# |KZT              |NULL                         |Казахстанський тенге                |
# |CAD              |Canadian Dollar              |Канадський долар                    |
# |CAD              |NULL                         |Канадський долар                    |
# |CYP              |NULL                         |Кипрский фунт                       |
# |CZK              |NULL                         |Коруна                              |
# |EEK              |NULL                         |Крони Естонії                       |
# |KWD              |NULL                         |Кувейтський динар                   |
# |KWD              |NULL                         |Кувейтські динари                   |
# |HRK              |NULL                         |Куна                                |
# |HRK              |Kuna                         |Куна                                |
# |GEL              |NULL                         |Ларi                                |
# |GEL              |Lari                         |Ларі                                |
# |LVL              |NULL                         |Латвійський лат                     |
# |LVL              |NULL                         |Лати Латвії                         |
# |BGL              |NULL                         |Лев (Болгарія)                      |
# |ROL              |NULL                         |Лей (Румунія)                       |
# |LTL              |NULL                         |Литовський літ                      |
# |LTL              |NULL                         |Литовські лити                      |
# |LBP              |NULL                         |Ліванський фунт                     |
# |LBP              |Lebanese Pound               |Ліванський фунт                     |
# |LYD              |NULL                         |Лівійський динар                    |
# |LYD              |Libyan Dinar                 |Лівійський динар                    |
# |MYR              |Malaysian Ringgit            |Малайзійський ринггіт               |
# |MYR              |NULL                         |Малайзійський ринггіт               |
# |MTP              |NULL                         |Мальтійська ліра                    |
# |MTL              |NULL                         |Мальтійська ліра                    |
# |MTL              |NULL                         |Мальтійські ліри                    |
# |TMM              |NULL                         |Манати Туркменії                    |
# |FIM              |NULL                         |Марка (Фінляндія)                   |
# |MAD              |NULL                         |Марокканський дирхам                |
# |MAD              |Moroccan Dirham              |Марокканський дирхам                |
# |MXN              |Mexican Peso                 |Мексиканське песо                   |
# |MXN              |NULL                         |Мексіканський песо                  |
# |MDL              |Moldovan Leu                 |Молдовський лей                     |
# |MDL              |NULL                         |Молдовський лей                     |
# |MNT              |NULL                         |Монгольский тугрик                  |
# |NLG              |NULL                         |Нiдерландський гульден              |
# |TWD              |NULL                         |Новий тайванський долар             |
# |TWD              |New Taiwan Dollar            |Новий тайванський долар             |
# |ILS              |NULL                         |Новий ізраїльський шекель           |
# |ILS              |New Israeli Sheqel           |Новий ізраїльський шекель           |
# |NZD              |NULL                         |Новозеландський долар               |
# |NZD              |New Zealand Dollar           |Новозеландський долар               |
# |NOK              |NULL                         |Норвезька крона                     |
# |NOK              |Norwegian Krone              |Норвезька крона                     |
# |DEM              |NULL                         |Німецька марка                      |
# |PKR              |NULL                         |Пакистанська рупія                  |
# |PKR              |Pakistan Rupee               |Пакистанська рупія                  |
# |XPD              |Palladium                    |Паладiй                             |
# |XPD              |NULL                         |Паладiй                             |
# |XPD              |Palladium                    |Паладій                             |
# |PEN              |NULL                         |Перуанский соль                     |
# |XPT              |Platinum                     |Платина                             |
# |XPT              |NULL                         |Платина                             |
# |PTE              |NULL                         |Португальський ескудо               |
# |PTE              |NULL                         |Португальські ескудо                |
# |KPW              |NULL                         |Північнокрейський вон               |
# |ZAR              |Rand                         |Ренд                                |
# |ZAR              |NULL                         |Ренд                                |
# |RUB              |NULL                         |Російський рубль                    |
# |RUB              |Russian Ruble                |Російський рубль                    |
# |RUR              |NULL                         |Російський рубль                    |
# |RUR              |NULL                         |Російські рублі                     |
# |RON              |Romanian Leu                 |Румунський лей                      |
# |ROL              |NULL                         |Румунський лей                      |
# |RON              |NULL                         |Румунський лей                      |
# |IDR              |NULL                         |Рупія                               |
# |IDR              |Rupiah                       |Рупія                               |
# |XDR              |SDR (Special Drawing Right)  |СПЗ (спеціальні права запозичення)  |
# |XDR              |NULL                         |СПЗ(спец.права запозичення)         |
# |XDR              |NULL                         |СПЗ(спеціальні права запозичення)   |
# |SAR              |NULL                         |Саудівський рiал                    |
# |SAR              |NULL                         |Саудівський рiял                    |
# |SAR              |Saudi Riyal                  |Саудівський рiял                    |
# |SAR              |Saudi Riyal                  |Саудівський ріял                    |
# |RSD              |Serbian Dinar                |Сербський динар                     |
# |RSD              |NULL                         |Сербський динар                     |
# |SYP              |NULL                         |Сирійский фунт                      |
# |SKK              |NULL                         |Словацька крона                     |
# |SKK              |NULL                         |Словацькі крони                     |
# |SIT              |NULL                         |Словенський толар                   |
# |SIT              |NULL                         |Словенські толари                   |
# |KGS              |Som                          |Сом                                 |
# |KGS              |NULL                         |Сом                                 |
# |KGS              |NULL                         |Сом (Киргизстан)                    |
# |TJS              |NULL                         |Сомонi                              |
# |TJS              |Somoni                       |Сомоні                              |
# |XDR              |NULL                         |Спецiальнi права запозичення        |
# |SDR              |NULL                         |Спецiальнi права запозичення        |
# |XAG              |NULL                         |Срiбло                              |
# |XAG              |Silver                       |Срiбло                              |
# |XAG              |Silver                       |Срібло                              |
# |SGD              |Singapore Dollar             |Сінгапурський долар                 |
# |SGD              |NULL                         |Сінгапурський долар                 |
# |TJS              |NULL                         |Таджикистанський сомоні             |
# |BDT              |NULL                         |Така                                |
# |BDT              |Taka                         |Така                                |
# |KZT              |Tenge                        |Теньге                              |
# |KZT              |NULL                         |Теньге                              |
# |SIT              |NULL                         |Толар (Словенія)                    |
# |TND              |Tunisian Dinar               |Туніський динар                     |
# |TND              |NULL                         |Туніський динар                     |
# |TRL              |NULL                         |Турецька ліра                       |
# |TRY              |NULL                         |Турецька ліра                       |
# |TRY              |Turkish Lira                 |Турецька ліра                       |
# |TRL              |NULL                         |Турецькі ліри                       |
# |TMT              |NULL                         |Туркменський манат                  |
# |TMM              |NULL                         |Туркменський манат                  |
# |TMT              |Turkmenistan New Manat       |Туркменський новий  манат           |
# |TMT              |Turkmenistan New Manat       |Туркменський новий манат            |
# |TMT              |NULL                         |Туркменський новий манат            |
# |UZS              |Uzbekistan Som               |Узбецький сум                       |
# |UZS              |Uzbekistan Sum               |Узбецький сум                       |
# |UZS              |NULL                         |Узбецький сум                       |
# |USM              |NULL                         |Узбецький сум                       |
# |FRF              |NULL                         |Фpанцузський фpанк                  |
# |HUF              |NULL                         |Форинт                              |
# |HUF              |Forint                       |Форинт                              |
# |HUF              |NULL                         |Форинт (Угорщина)                   |
# |XOF              |NULL                         |Франки CFA-BCEAO                    |
# |FRF              |NULL                         |Французький франк                   |
# |GBP              |Pound Sterling               |Фунт стерлінгів                     |
# |GBP              |NULL                         |Фунт стерлінгів                     |
# |PHP              |Philippine Piso              |Філіппінське песо                   |
# |ZAL              |NULL                         |Фінансовий ренд ПАР                 |
# |FIM              |NULL                         |Фінські маpки                       |
# |HRK              |NULL                         |Хорватська куна                     |
# |CZK              |NULL                         |Чеська крона                        |
# |CZK              |Czech Koruna                 |Чеська крона                        |
# |CLP              |NULL                         |Чілійські песо                      |
# |SEK              |NULL                         |Шведська крона                      |
# |SEK              |Swedish Krona                |Шведська крона                      |
# |CHF              |NULL                         |Швейцарський франк                  |
# |CHF              |Swiss Franc                  |Швейцарський франк                  |
# |ATS              |NULL                         |Шилінг (Австрія)                    |
# |CNY              |Yuan Renminbi                |Юань Женьмiньбi                     |
# |CNY              |NULL                         |Юань Женьмiньбi                     |
# |CNY              |Yuan Renminbi                |Юань Женьміньбі                     |
# |ROL              |NULL                         |новий румунські леї                 |
# --------------------------------------------------------------------------------------

# %%
exchange_rate_extracted_df \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .order_by('currency_name_ua') \
    .count()

# 221
# Out:
# 221

# %%
exchange_rate_extracted_df \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .where(col("currency_name").isNull()) \
    .show(150)
# Out:
# -------------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"  |"CURRENCY_NAME_UA"                 |
# -------------------------------------------------------------------------
# |NOK              |NULL             |Норвезька крона                    |
# |CAD              |NULL             |Канадський долар                   |
# |TMM              |NULL             |Туркменський манат                 |
# |ROL              |NULL             |Лей (Румунія)                      |
# |GRD              |NULL             |Грецька драхма                     |
# |SIT              |NULL             |Словенський толар                  |
# |XEU              |NULL             |ЕКЮ                                |
# |SKK              |NULL             |Словацькі крони                    |
# |PTE              |NULL             |Португальські ескудо               |
# |IQD              |NULL             |Іракський динар                    |
# |LYD              |NULL             |Лівійський динар                   |
# |ROL              |NULL             |новий румунські леї                |
# |SIT              |NULL             |Словенські толари                  |
# |GEL              |NULL             |Грузинські ларі                    |
# |CHF              |NULL             |Швейцарський франк                 |
# |SKK              |NULL             |Словацька крона                    |
# |PLZ              |NULL             |Злотий                             |
# |SDR              |NULL             |Спецiальнi права запозичення       |
# |CZK              |NULL             |Коруна                             |
# |SIT              |NULL             |Толар (Словенія)                   |
# |EEK              |NULL             |Естонська крона                    |
# |MTP              |NULL             |Мальтійська ліра                   |
# |AMD              |NULL             |Вiрменський драм                   |
# |ROL              |NULL             |Румунський лей                     |
# |TRL              |NULL             |Турецькі ліри                      |
# |FRF              |NULL             |Фpанцузський фpанк                 |
# |IEP              |NULL             |Ірландські фунти                   |
# |IRR              |NULL             |Іранський ріал                     |
# |PKR              |NULL             |Пакистанська рупія                 |
# |TRY              |NULL             |Турецька ліра                      |
# |BGN              |NULL             |Болгарський лев                    |
# |RON              |NULL             |Румунський лей                     |
# |DZD              |NULL             |Алжирський динар                   |
# |ZAR              |NULL             |Ренд                               |
# |SEK              |NULL             |Шведська крона                     |
# |ITL              |NULL             |Італійська ліра                    |
# |FRF              |NULL             |Французький франк                  |
# |BEF              |NULL             |Бельгійський франк                 |
# |EGP              |NULL             |Єгипетський фунт                   |
# |INR              |NULL             |Індійська рупія                    |
# |HKD              |NULL             |Долар Гонконгу                     |
# |BGL              |NULL             |Лев (Болгарія)                     |
# |USM              |NULL             |Узбецький сум                      |
# |CZK              |NULL             |Чеська крона                       |
# |KZT              |NULL             |Теньге                             |
# |MTL              |NULL             |Мальтійська ліра                   |
# |GBP              |NULL             |Фунт стерлінгів                    |
# |ESP              |NULL             |Іспанскі пессети                   |
# |LTL              |NULL             |Литовські лити                     |
# |XDR              |NULL             |СПЗ(спец.права запозичення)        |
# |IDR              |NULL             |Рупія                              |
# |TND              |NULL             |Туніський динар                    |
# |ATS              |NULL             |Шилінг (Австрія)                   |
# |ILS              |NULL             |Новий ізраїльський шекель          |
# |MDL              |NULL             |Молдовський лей                    |
# |XPT              |NULL             |Платина                            |
# |XAG              |NULL             |Срiбло                             |
# |PLN              |NULL             |Злотий                             |
# |BYB              |NULL             |Бiлоруський рубль                  |
# |UZS              |NULL             |Узбецький сум                      |
# |XDR              |NULL             |Спецiальнi права запозичення       |
# |EEK              |NULL             |Крони Естонії                      |
# |FIM              |NULL             |Фінські маpки                      |
# |GRD              |NULL             |Грецькі драхми                     |
# |VND              |NULL             |Донг                               |
# |HRK              |NULL             |Куна                               |
# |MNT              |NULL             |Монгольский тугрик                 |
# |PEN              |NULL             |Перуанский соль                    |
# |XOF              |NULL             |Франки CFA-BCEAO                   |
# |EUR              |NULL             |Євро                               |
# |TJS              |NULL             |Сомонi                             |
# |CYP              |NULL             |Кипрский фунт                      |
# |AED              |NULL             |Дирхам ОАЕ                         |
# |MAD              |NULL             |Марокканський дирхам               |
# |TMT              |NULL             |Туркменський новий манат           |
# |GHS              |NULL             |Ганських седі                      |
# |NLG              |NULL             |Нiдерландський гульден             |
# |DEM              |NULL             |Німецька марка                     |
# |ESP              |NULL             |Іспанська песета                   |
# |KWD              |NULL             |Кувейтський динар                  |
# |ISK              |NULL             |Ісландська крона                   |
# |CNY              |NULL             |Юань Женьмiньбi                    |
# |IEP              |NULL             |Ірландський фунт                   |
# |LVL              |NULL             |Латвійський лат                    |
# |WDR              |NULL             |Вiрменський драм                   |
# |GEL              |NULL             |Ларi                               |
# |BYR              |NULL             |Бiлоруський рубль                  |
# |XAU              |NULL             |Золото                             |
# |HRK              |NULL             |Хорватська куна                    |
# |GEK              |NULL             |Грузинський купон                  |
# |NLG              |NULL             |Голандські гульдени                |
# |BRL              |NULL             |Бразильський реал                  |
# |MXN              |NULL             |Мексіканський песо                 |
# |SAR              |NULL             |Саудівський рiял                   |
# |SYP              |NULL             |Сирійский фунт                     |
# |BYN              |NULL             |Бiлоруський рубль                  |
# |THB              |NULL             |Бат                                |
# |MYR              |NULL             |Малайзійський ринггіт              |
# |DKK              |NULL             |Данська крона                      |
# |JPY              |NULL             |Єна                                |
# |AUD              |NULL             |Австралійський долар               |
# |GRD              |NULL             |Драхма (Греція)                    |
# |TRL              |NULL             |Турецька ліра                      |
# |FIM              |NULL             |Марка (Фінляндія)                  |
# |RUR              |NULL             |Російський рубль                   |
# |XEU              |NULL             |Екю                                |
# |HUF              |NULL             |Форинт                             |
# |BGL              |NULL             |Болгарські леви                    |
# |ISK              |NULL             |Ісландські крони                   |
# |LBP              |NULL             |Ліванський фунт                    |
# |MTL              |NULL             |Мальтійські ліри                   |
# |ZAL              |NULL             |Фінансовий ренд ПАР                |
# |TMT              |NULL             |Туркменський манат                 |
# |RSD              |NULL             |Сербський динар                    |
# |BDT              |NULL             |Така                               |
# |XDR              |NULL             |СПЗ(спеціальні права запозичення)  |
# |USD              |NULL             |Долар США                          |
# |HRD              |NULL             |Динар                              |
# |TWD              |NULL             |Новий тайванський долар            |
# |AZM              |NULL             |Азербайджанський манат             |
# |CLP              |NULL             |Чілійські песо                     |
# |HUF              |NULL             |Форинт (Угорщина)                  |
# |KGS              |NULL             |Сом (Киргизстан)                   |
# |XOF              |NULL             |КФА франк BCEAO                    |
# |KRW              |NULL             |Вон (Республіка Корея)             |
# |ATS              |NULL             |Австрійський шилінг                |
# |KRW              |NULL             |Вона                               |
# |KGS              |NULL             |Сом                                |
# |HKD              |NULL             |Гонконгівський долар               |
# |RUR              |NULL             |Російські рублі                    |
# |ITL              |NULL             |Італійські ліpи                    |
# |LVL              |NULL             |Лати Латвії                        |
# |TMM              |NULL             |Манати Туркменії                   |
# |DEM              |NULL             |Hімецькі маpки                     |
# |ECS              |NULL             |Еквадорський сукре                 |
# |TJS              |NULL             |Таджикистанський сомоні            |
# |XPD              |NULL             |Паладiй                            |
# |LTL              |NULL             |Литовський літ                     |
# |SGD              |NULL             |Сінгапурський долар                |
# |NZD              |NULL             |Новозеландський долар              |
# |KZT              |NULL             |Казахстанський тенге               |
# |GBP              |NULL             |Англійський фунт стерлінгів        |
# |SAR              |NULL             |Саудівський рiал                   |
# |PTE              |NULL             |Португальський ескудо              |
# |KWD              |NULL             |Кувейтські динари                  |
# |KPW              |NULL             |Північнокрейський вон              |
# |___              |NULL             |Долари США по розр. з Індією       |
# |RUB              |NULL             |Російський рубль                   |
# |AZN              |NULL             |Азербайджанський манат             |
# -------------------------------------------------------------------------

# %%
exchange_rate_extracted_df \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .where(col("currency_name").isNull()) \
    .count()

# 149
# Out:
# 149

# %%
exchange_rate_extracted_df \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .where(col("currency_code") == "AUD") \
    .order_by(col("currency_name").desc()) \
    .show(10)
# Out:
# --------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"    |"CURRENCY_NAME_UA"    |
# --------------------------------------------------------------
# |AUD              |Australian Dollar  |Австралійський долар  |
# |AUD              |NULL               |Австралійський долар  |
# --------------------------------------------------------------

# %%
from snowflake.snowpark import Window
from snowflake.snowpark.functions import coalesce, first_value, trim, upper

# To fill in nulls in currency_name with value from currency_name that has the same code

windows = Window.partition_by(trim(upper(col("currency_code")))).order_by(col("currency_name").desc())

exchange_rate_extracted_df_m = exchange_rate_extracted_df \
    .with_column(
        "currency_name",
        coalesce(
            col("currency_name"),
            first_value(col("currency_name")).over(windows)
        )
    )

# %%
exchange_rate_extracted_df_m \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .order_by('currency_name_ua') \
    .count()

# 165
# Out:
# 165

# %%
exchange_rate_extracted_df_m \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .order_by('currency_name_ua') \
    .show(170)
# Out:
# --------------------------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"              |"CURRENCY_NAME_UA"                  |
# --------------------------------------------------------------------------------------
# |DEM              |NULL                         |Hімецькі маpки                      |
# |EUR              |Euro                         |Євро                                |
# |EGP              |Egyptian Pound               |Єгипетський фунт                    |
# |JPY              |Yen                          |Єна                                 |
# |INR              |Indian Rupee                 |Індійська рупія                     |
# |IQD              |Iraqi Dinar                  |Іракський динар                     |
# |IRR              |Iranian Rial                 |Іранський ріал                      |
# |IEP              |NULL                         |Ірландський фунт                    |
# |IEP              |NULL                         |Ірландські фунти                    |
# |ISK              |NULL                         |Ісландська крона                    |
# |ISK              |NULL                         |Ісландські крони                    |
# |ESP              |NULL                         |Іспанскі пессети                    |
# |ESP              |NULL                         |Іспанська песета                    |
# |ITL              |NULL                         |Італійська ліра                     |
# |ITL              |NULL                         |Італійські ліpи                     |
# |AUD              |Australian Dollar            |Австралійський долар                |
# |ATS              |NULL                         |Австрійський шилінг                 |
# |AZM              |NULL                         |Азербайджанський манат              |
# |AZN              |Azerbaijan Manat             |Азербайджанський манат              |
# |DZD              |Algerian Dinar               |Алжирський динар                    |
# |GBP              |Pound Sterling               |Англійський фунт стерлінгів         |
# |BYB              |NULL                         |Бiлоруський рубль                   |
# |BYR              |NULL                         |Бiлоруський рубль                   |
# |BYN              |Belarusian Ruble             |Бiлоруський рубль                   |
# |THB              |Baht                         |Бат                                 |
# |BEF              |NULL                         |Бельгійський франк                  |
# |BGN              |Bulgarian Lev                |Болгарський лев                     |
# |BGL              |NULL                         |Болгарські леви                     |
# |BRL              |Brazilian Real               |Бразильський реал                   |
# |BYN              |Belarusian Ruble             |Білоруський рубль                   |
# |AMD              |Armenian Dram                |Вiрменський драм                    |
# |WDR              |NULL                         |Вiрменський драм                    |
# |KRW              |Won                          |Вон (Республіка Корея)              |
# |KRW              |Won                          |Вона                                |
# |AMD              |Armenian Dram                |Вірменський драм                    |
# |GHS              |Ghana Cedi                   |Ганське седі                        |
# |GHS              |Ghana Cedi                   |Ганських седі                       |
# |NLG              |NULL                         |Голандські гульдени                 |
# |HKD              |Hong Kong Dollar             |Гонконгівський долар                |
# |GRD              |NULL                         |Грецька драхма                      |
# |GRD              |NULL                         |Грецькі драхми                      |
# |GEK              |NULL                         |Грузинський купон                   |
# |GEL              |Lari                         |Грузинські ларі                     |
# |DKK              |Danish Krone                 |Данська крона                       |
# |HRD              |NULL                         |Динар                               |
# |AED              |UAE Dirham                   |Дирхам ОАЕ                          |
# |HKD              |Hong Kong Dollar             |Долар Гонконгу                      |
# |USD              |United States dollar         |Долар США                           |
# |USD              |US Dollar                    |Долар США                           |
# |___              |NULL                         |Долари США по розр. з Індією        |
# |DOP              |Dominican Peso               |Домініканське песо                  |
# |VND              |Dong                         |Донг                                |
# |GRD              |NULL                         |Драхма (Греція)                     |
# |XEU              |NULL                         |ЕКЮ                                 |
# |ECS              |NULL                         |Еквадорський сукре                  |
# |XEU              |NULL                         |Екю                                 |
# |EEK              |NULL                         |Естонська крона                     |
# |PLN              |Zloty                        |Злотий                              |
# |PLZ              |NULL                         |Злотий                              |
# |XAU              |Gold                         |Золото                              |
# |XOF              |NULL                         |КФА франк BCEAO                     |
# |KZT              |Tenge                        |Казахстанський тенге                |
# |CAD              |Canadian Dollar              |Канадський долар                    |
# |CYP              |NULL                         |Кипрский фунт                       |
# |CZK              |Czech Koruna                 |Коруна                              |
# |EEK              |NULL                         |Крони Естонії                       |
# |KWD              |NULL                         |Кувейтський динар                   |
# |KWD              |NULL                         |Кувейтські динари                   |
# |HRK              |Kuna                         |Куна                                |
# |GEL              |Lari                         |Ларi                                |
# |GEL              |Lari                         |Ларі                                |
# |LVL              |NULL                         |Латвійський лат                     |
# |LVL              |NULL                         |Лати Латвії                         |
# |BGL              |NULL                         |Лев (Болгарія)                      |
# |ROL              |NULL                         |Лей (Румунія)                       |
# |LTL              |NULL                         |Литовський літ                      |
# |LTL              |NULL                         |Литовські лити                      |
# |LBP              |Lebanese Pound               |Ліванський фунт                     |
# |LYD              |Libyan Dinar                 |Лівійський динар                    |
# |MYR              |Malaysian Ringgit            |Малайзійський ринггіт               |
# |MTL              |NULL                         |Мальтійська ліра                    |
# |MTP              |NULL                         |Мальтійська ліра                    |
# |MTL              |NULL                         |Мальтійські ліри                    |
# |TMM              |NULL                         |Манати Туркменії                    |
# |FIM              |NULL                         |Марка (Фінляндія)                   |
# |MAD              |Moroccan Dirham              |Марокканський дирхам                |
# |MXN              |Mexican Peso                 |Мексиканське песо                   |
# |MXN              |Mexican Peso                 |Мексіканський песо                  |
# |MDL              |Moldovan Leu                 |Молдовський лей                     |
# |MNT              |NULL                         |Монгольский тугрик                  |
# |NLG              |NULL                         |Нiдерландський гульден              |
# |TWD              |New Taiwan Dollar            |Новий тайванський долар             |
# |ILS              |New Israeli Sheqel           |Новий ізраїльський шекель           |
# |NZD              |New Zealand Dollar           |Новозеландський долар               |
# |NOK              |Norwegian Krone              |Норвезька крона                     |
# |DEM              |NULL                         |Німецька марка                      |
# |PKR              |Pakistan Rupee               |Пакистанська рупія                  |
# |XPD              |Palladium                    |Паладiй                             |
# |XPD              |Palladium                    |Паладій                             |
# |PEN              |NULL                         |Перуанский соль                     |
# |XPT              |Platinum                     |Платина                             |
# |PTE              |NULL                         |Португальський ескудо               |
# |PTE              |NULL                         |Португальські ескудо                |
# |KPW              |NULL                         |Північнокрейський вон               |
# |ZAR              |Rand                         |Ренд                                |
# |RUR              |NULL                         |Російський рубль                    |
# |RUB              |Russian Ruble                |Російський рубль                    |
# |RUR              |NULL                         |Російські рублі                     |
# |ROL              |NULL                         |Румунський лей                      |
# |RON              |Romanian Leu                 |Румунський лей                      |
# |IDR              |Rupiah                       |Рупія                               |
# |XDR              |SDR (Special Drawing Right)  |СПЗ (спеціальні права запозичення)  |
# |XDR              |SDR (Special Drawing Right)  |СПЗ(спец.права запозичення)         |
# |XDR              |SDR (Special Drawing Right)  |СПЗ(спеціальні права запозичення)   |
# |SAR              |Saudi Riyal                  |Саудівський рiал                    |
# |SAR              |Saudi Riyal                  |Саудівський рiял                    |
# |SAR              |Saudi Riyal                  |Саудівський ріял                    |
# |RSD              |Serbian Dinar                |Сербський динар                     |
# |SYP              |NULL                         |Сирійский фунт                      |
# |SKK              |NULL                         |Словацька крона                     |
# |SKK              |NULL                         |Словацькі крони                     |
# |SIT              |NULL                         |Словенський толар                   |
# |SIT              |NULL                         |Словенські толари                   |
# |KGS              |Som                          |Сом                                 |
# |KGS              |Som                          |Сом (Киргизстан)                    |
# |TJS              |Somoni                       |Сомонi                              |
# |TJS              |Somoni                       |Сомоні                              |
# |XDR              |SDR (Special Drawing Right)  |Спецiальнi права запозичення        |
# |SDR              |NULL                         |Спецiальнi права запозичення        |
# |XAG              |Silver                       |Срiбло                              |
# |XAG              |Silver                       |Срібло                              |
# |SGD              |Singapore Dollar             |Сінгапурський долар                 |
# |TJS              |Somoni                       |Таджикистанський сомоні             |
# |BDT              |Taka                         |Така                                |
# |KZT              |Tenge                        |Теньге                              |
# |SIT              |NULL                         |Толар (Словенія)                    |
# |TND              |Tunisian Dinar               |Туніський динар                     |
# |TRY              |Turkish Lira                 |Турецька ліра                       |
# |TRL              |NULL                         |Турецька ліра                       |
# |TRL              |NULL                         |Турецькі ліри                       |
# |TMM              |NULL                         |Туркменський манат                  |
# |TMT              |Turkmenistan New Manat       |Туркменський манат                  |
# |TMT              |Turkmenistan New Manat       |Туркменський новий  манат           |
# |TMT              |Turkmenistan New Manat       |Туркменський новий манат            |
# |USM              |NULL                         |Узбецький сум                       |
# |UZS              |Uzbekistan Sum               |Узбецький сум                       |
# |UZS              |Uzbekistan Som               |Узбецький сум                       |
# |FRF              |NULL                         |Фpанцузський фpанк                  |
# |HUF              |Forint                       |Форинт                              |
# |HUF              |Forint                       |Форинт (Угорщина)                   |
# |XOF              |NULL                         |Франки CFA-BCEAO                    |
# |FRF              |NULL                         |Французький франк                   |
# |GBP              |Pound Sterling               |Фунт стерлінгів                     |
# |PHP              |Philippine Piso              |Філіппінське песо                   |
# |ZAL              |NULL                         |Фінансовий ренд ПАР                 |
# |FIM              |NULL                         |Фінські маpки                       |
# |HRK              |Kuna                         |Хорватська куна                     |
# |CZK              |Czech Koruna                 |Чеська крона                        |
# |CLP              |NULL                         |Чілійські песо                      |
# |SEK              |Swedish Krona                |Шведська крона                      |
# |CHF              |Swiss Franc                  |Швейцарський франк                  |
# |ATS              |NULL                         |Шилінг (Австрія)                    |
# |CNY              |Yuan Renminbi                |Юань Женьмiньбi                     |
# |CNY              |Yuan Renminbi                |Юань Женьміньбі                     |
# |ROL              |NULL                         |новий румунські леї                 |
# --------------------------------------------------------------------------------------

# %%
iso_4217_currency_codes_df = session.table("nbu_exchange.silver.iso_4217_currencies")
iso_4217_currency_codes_df.show(5)
# Out:
# -------------------------------------------------------------------------------------------------------------------------
# |"COUNTRY_NAME"       |"CURRENCY_NAME"        |"CURRENCY_CODE"  |"CURRENCY_NUMBER"  |"MINOR_UNITS"  |"WITHDRAWAL_DATE"  |
# -------------------------------------------------------------------------------------------------------------------------
# |ANTARCTICA           |No universal currency  |NULL             |NULL               |NULL           |NULL               |
# |ANTIGUA AND BARBUDA  |East Caribbean Dollar  |XCD              |951                |2              |NULL               |
# |AUSTRIA              |Euro                   |EUR              |978                |2              |NULL               |
# |COOK ISLANDS (THE)   |New Zealand Dollar     |NZD              |554                |2              |NULL               |
# |MALTA                |Euro                   |EUR              |978                |2              |NULL               |
# -------------------------------------------------------------------------------------------------------------------------

# %%
iso_4217_currency_codes_df_m = iso_4217_currency_codes_df \
    .select(
        col("country_name"),
        col("currency_name").alias("iso_currency_name"),
        col("currency_code").alias("iso_currency_code"),
        col("withdrawal_date")
    )

# %%
exchange_rate_extracted_df_u = exchange_rate_extracted_df_m \
    .join(
        iso_4217_currency_codes_df_m,
        trim(upper(exchange_rate_extracted_df_m.currency_code)) == iso_4217_currency_codes_df_m.iso_currency_code,
        "left"
    ) \
    .select(
        exchange_rate_extracted_df_m["*"],
        iso_4217_currency_codes_df_m["country_name"],
        iso_4217_currency_codes_df_m["iso_currency_name"],
        iso_4217_currency_codes_df_m["withdrawal_date"]
    ) \
    .withColumn("currency_name", coalesce(col("currency_name"), col("iso_currency_name"))) \
    .drop("iso_currency_name")

# %%
exchange_rate_extracted_df_u.show(5)
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"CURRENCY_CODE"  |"GROUP_NUMBER"  |"R030_CODE"  |"RATE"    |"RATE_PER_UNIT"  |"SPECIAL_CONDITIONS"  |"CURRENCY_NAME_UA"  |"UNITS"  |"CALCULATION_DATE"  |"EXCHANGE_DATE"  |"COUNTRY_NAME"             |"WITHDRAWAL_DATE"  |"CURRENCY_NAME"  |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |KZT              |1               |398          |11.1296   |0.111296         |NULL                  |Теньге              |100      |1900-01-01          |2015-05-22       |KAZAKHSTAN                 |NULL               |Tenge            |
# |MDL              |1               |498          |116.8078  |1.168078         |NULL                  |Молдовський лей     |100      |1900-01-01          |2015-05-22       |MOLDOVA (THE REPUBLIC OF)  |NULL               |Moldovan Leu     |
# |NOK              |1               |578          |272.9958  |2.729958         |NULL                  |Норвезька крона     |100      |1900-01-01          |2015-05-22       |NORWAY                     |NULL               |Norwegian Krone  |
# |NOK              |1               |578          |272.9958  |2.729958         |NULL                  |Норвезька крона     |100      |1900-01-01          |2015-05-22       |BOUVET ISLAND              |NULL               |Norwegian Krone  |
# |NOK              |1               |578          |272.9958  |2.729958         |NULL                  |Норвезька крона     |100      |1900-01-01          |2015-05-22       |SVALBARD AND JAN MAYEN     |NULL               |Norwegian Krone  |
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
exchange_rate_extracted_df_u \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .where(col("currency_name").isNull()) \
    .order_by(col("currency_name_ua").desc()) \
    .show(10)
# Out:
# --------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"  |"CURRENCY_NAME_UA"            |
# --------------------------------------------------------------------
# |USM              |NULL             |Узбецький сум                 |
# |SDR              |NULL             |Спецiальнi права запозичення  |
# |___              |NULL             |Долари США по розр. з Індією  |
# |WDR              |NULL             |Вiрменський драм              |
# --------------------------------------------------------------------

# %%
iso_4217_currency_codes_df \
    .where((col("currency_code") == "USM") | (col("currency_code") == "SDR") | (col("currency_code") == "WDR")) \
    .show(10)
# Out:
# --------------------------------------------------------------------------------------------------------------
# |"COUNTRY_NAME"  |"CURRENCY_NAME"  |"CURRENCY_CODE"  |"CURRENCY_NUMBER"  |"MINOR_UNITS"  |"WITHDRAWAL_DATE"  |
# --------------------------------------------------------------------------------------------------------------
# |                |                 |                 |                   |               |                   |
# --------------------------------------------------------------------------------------------------------------

# %%
exchange_rate_extracted_df.where(col("currency_code") == "USM").count()
# Out:
# 664

# %%
exchange_rate_extracted_df_u \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .where(col("currency_name_ua").like("%Узбецький сум%")) \
    .show(10)

# USM code is not valid for Uzbekistan Som
# Out:
# ----------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"  |"CURRENCY_NAME_UA"  |
# ----------------------------------------------------------
# |UZS              |Uzbekistan Som   |Узбецький сум       |
# |USM              |NULL             |Узбецький сум       |
# |UZS              |Uzbekistan Sum   |Узбецький сум       |
# ----------------------------------------------------------

# %%
iso_4217_currency_codes_df \
    .where((col("currency_code") == "UZS")) \
    .show(10)
# Out:
# --------------------------------------------------------------------------------------------------------------
# |"COUNTRY_NAME"  |"CURRENCY_NAME"  |"CURRENCY_CODE"  |"CURRENCY_NUMBER"  |"MINOR_UNITS"  |"WITHDRAWAL_DATE"  |
# --------------------------------------------------------------------------------------------------------------
# |UZBEKISTAN      |Uzbekistan Sum   |UZS              |860                |2              |NULL               |
# --------------------------------------------------------------------------------------------------------------

# %%
# |USM              |NULL             |Узбецький сум                 |
exchange_rate_extracted_df_uzs = exchange_rate_extracted_df_u \
    .withColumn("currency_code", when(col("currency_code") == "USM", "UZS").otherwise(col("currency_code"))) \
    .withColumn("currency_name", 
                when((col("currency_code") == "UZS") 
                     & ((col("currency_name") != "Uzbekistan Sum") | (col("currency_name").isNull())), 
                     "Uzbekistan Sum") \
                     .otherwise(col("currency_name")))

# %%
exchange_rate_extracted_df_uzs.select("currency_code", "currency_name", "currency_name_ua").distinct().where(col("currency_code") == "UZS").show(5)
# Out:
# ----------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"  |"CURRENCY_NAME_UA"  |
# ----------------------------------------------------------
# |UZS              |Uzbekistan Sum   |Узбецький сум       |
# ----------------------------------------------------------

# %%
# |WDR              |NULL             |Вiрменський драм              |
exchange_rate_extracted_df_uzs.select("currency_code", "currency_name", "currency_name_ua").distinct().where(col("currency_name_ua").like("%Вiрменський драм%")).show(5)

iso_4217_currency_codes_df \
    .where((col("currency_code") == "AMD")) \
    .show(10)

exchange_rate_extracted_df_amd = exchange_rate_extracted_df_uzs \
    .withColumn("currency_code", when(col("currency_code") == "WDR", "AMD").otherwise(col("currency_code"))) \
    .withColumn("currency_name", when((col("currency_code") == "AMD") & col("currency_name").isNull(), "Armenian Dram").otherwise(col("currency_name")))

exchange_rate_extracted_df_amd.select("currency_code", "currency_name", "currency_name_ua", "r030_code").distinct().where(col("currency_code") == "AMD").show(5)
# Out:
# ----------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"  |"CURRENCY_NAME_UA"  |
# ----------------------------------------------------------
# |WDR              |NULL             |Вiрменський драм    |
# |AMD              |Armenian Dram    |Вiрменський драм    |
# ----------------------------------------------------------
#
# --------------------------------------------------------------------------------------------------------------
# |"COUNTRY_NAME"  |"CURRENCY_NAME"  |"CURRENCY_CODE"  |"CURRENCY_NUMBER"  |"MINOR_UNITS"  |"WITHDRAWAL_DATE"  |
# --------------------------------------------------------------------------------------------------------------
# |ARMENIA         |Armenian Dram    |AMD              |51                 |2              |NULL               |
# --------------------------------------------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"  |"CURRENCY_NAME_UA"  |"R030_CODE"  |
# ------------------------------------------------------------------------
# |AMD              |Armenian Dram    |Вірменський драм    |51           |
# |AMD              |Armenian Dram    |Вiрменський драм    |944          |
# |AMD              |Armenian Dram    |Вiрменський драм    |51           |
# ------------------------------------------------------------------------

# %%
# SDR              |NULL             |Спецiальнi права запозичення
# where currency_code = 'SDR' or currency_code = 'XDR' or r030_code = 960

exchange_rate_extracted_df_amd.select("currency_code", "currency_name", "currency_name_ua", "r030_code").distinct().where((col("currency_code") == "SDR") | (col("currency_code") == "XDR") | (col("r030_code") == 960)).show(20)

iso_4217_currency_codes_df.where((col("currency_code") == "SDR") | (col("currency_code") == "XDR")).show(10)

exchange_rate_extracted_df_xdr = exchange_rate_extracted_df_amd \
    .withColumn("currency_code", 
                when(col("currency_code") == "SDR", "XDR").otherwise(col("currency_code"))) \
    .withColumn("currency_name", 
                when((col("currency_code") == "XDR") & col("currency_name").isNull(), "SDR (Special Drawing Right)") \
                .otherwise(col("currency_name"))) \
    .withColumn("currency_name_ua", 
                when(col("currency_code") == "XDR", "СПЗ (спеціальні права запозичення)") \
                .otherwise(col("currency_name_ua")))

exchange_rate_extracted_df_xdr.select("currency_code", "currency_name", "currency_name_ua", "r030_code").distinct().where(col("currency_code") == "XDR").show(5)
# Out:
# ----------------------------------------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"              |"CURRENCY_NAME_UA"                  |"R030_CODE"  |
# ----------------------------------------------------------------------------------------------------
# |SDR              |NULL                         |Спецiальнi права запозичення        |12           |
# |XDR              |SDR (Special Drawing Right)  |Спецiальнi права запозичення        |960          |
# |XDR              |SDR (Special Drawing Right)  |СПЗ (спеціальні права запозичення)  |960          |
# |XDR              |SDR (Special Drawing Right)  |СПЗ(спеціальні права запозичення)   |960          |
# |XDR              |SDR (Special Drawing Right)  |СПЗ(спец.права запозичення)         |960          |
# ----------------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------------------------------------------------------
# |"COUNTRY_NAME"                     |"CURRENCY_NAME"              |"CURRENCY_CODE"  |"CURRENCY_NUMBER"  |"MINOR_UNITS"  |"WITHDRAWAL_DATE"  |
# ---------------------------------------------------------------------------------------------------------------------------------------------
# |INTERNATIONAL MONETARY FUND (IMF)  |SDR (Special Drawing Right)  |XDR              |960                |NULL           |NULL               |
# ---------------------------------------------------------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"              |"CURRENCY_NAME_UA"                  |"R030_CODE"  |
# ----------------------------------------------------------------------------------------------------
# |XDR              |SDR (Special Drawing Right)  |СПЗ (спеціальні права запозичення)  |12           |
# |XDR              |SDR (Special Drawing Right)  |СПЗ (спеціальні права запозичення)  |960          |
# ----------------------------------------------------------------------------------------------------

# %%
exchange_rate_extracted_df_xdr \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .where(col("currency_name").isNull()) \
    .order_by(col("currency_name_ua").desc()) \
    .show(10)
# Out:
# --------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"  |"CURRENCY_NAME_UA"            |
# --------------------------------------------------------------------
# |___              |NULL             |Долари США по розр. з Індією  |
# --------------------------------------------------------------------

# %%
# nbu_exchange.bronze.r030_csv_raw

# need to create separate df with currency_code that have duplicaitons
exchange_rate_extracted_df_xdr \
    .select('currency_code', 'currency_name', 'currency_name_ua', 'r030_code') \
    .distinct() \
    .groupBy('currency_code', 'currency_name', 'currency_name_ua') \
    .count() \
    .filter(col("count") > 1) \
    .orderBy(col("currency_code")) \
    .show(100) # 0
# Out:
# ---------------------------------------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"                 |"CURRENCY_NAME_UA"                  |"COUNT"  |
# ---------------------------------------------------------------------------------------------------
# |AMD              |Armenian Dram                   |Вiрменський драм                    |2        |
# |AUD              |Australian Dollar               |Австралійський долар                |2        |
# |AZM              |Azerbaijanian Manat             |Азербайджанський манат              |2        |
# |BEF              |Belgian Franc                   |Бельгійський франк                  |2        |
# |BYR              |Belarusian Ruble                |Бiлоруський рубль                   |2        |
# |CAD              |Canadian Dollar                 |Канадський долар                    |2        |
# |CHF              |Swiss Franc                     |Швейцарський франк                  |2        |
# |CLP              |Chilean Peso                    |Чілійські песо                      |2        |
# |DEM              |Deutsche Mark                   |Німецька марка                      |2        |
# |DKK              |Danish Krone                    |Данська крона                       |2        |
# |EGP              |Egyptian Pound                  |Єгипетський фунт                    |2        |
# |ESP              |Spanish Peseta                  |Іспанська песета                    |2        |
# |FIM              |Markka                          |Марка (Фінляндія)                   |2        |
# |FRF              |French Franc                    |Французький франк                   |2        |
# |GEL              |Lari                            |Ларi                                |2        |
# |IEP              |Irish Pound                     |Ірландський фунт                    |2        |
# |ILS              |New Israeli Sheqel              |Новий ізраїльський шекель           |2        |
# |INR              |Indian Rupee                    |Індійська рупія                     |2        |
# |ISK              |Iceland Krona                   |Ісландська крона                    |2        |
# |ITL              |Italian Lira                    |Італійська ліра                     |2        |
# |JPY              |Yen                             |Єна                                 |2        |
# |KWD              |Kuwaiti Dinar                   |Кувейтський динар                   |2        |
# |LTL              |Lithuanian Litas                |Литовський літ                      |2        |
# |MDL              |Moldovan Leu                    |Молдовський лей                     |2        |
# |NLG              |Netherlands Guilder             |Нiдерландський гульден              |2        |
# |NOK              |Norwegian Krone                 |Норвезька крона                     |2        |
# |NZD              |New Zealand Dollar              |Новозеландський долар               |2        |
# |PTE              |Portuguese Escudo               |Португальський ескудо               |2        |
# |RUR              |Russian Ruble                   |Російський рубль                    |2        |
# |SAR              |Saudi Riyal                     |Саудівський рiал                    |2        |
# |SEK              |Swedish Krona                   |Шведська крона                      |2        |
# |SGD              |Singapore Dollar                |Сінгапурський долар                 |2        |
# |SKK              |Slovak Koruna                   |Словацька крона                     |2        |
# |TMM              |Turkmenistan Manat              |Туркменський манат                  |2        |
# |TRL              |Old Turkish Lira                |Турецька ліра                       |2        |
# |TWD              |New Taiwan Dollar               |Новий тайванський долар             |2        |
# |USD              |United States dollar            |Долар США                           |2        |
# |UZS              |Uzbekistan Sum                  |Узбецький сум                       |2        |
# |XDR              |SDR (Special Drawing Right)     |СПЗ (спеціальні права запозичення)  |2        |
# |XEU              |European Currency Unit (E.C.U)  |Екю                                 |2        |
# ---------------------------------------------------------------------------------------------------

# %%
# Out:
# "select distinct currency_code, currency_name, currency_name_ua, r030_code\nfrom nbu_exchange.silver.exchange_rate_extracted\nwhere currency_code = 'SDR' or currency_code = 'XDR' or r030_code = 960\n;\n"

# %%
# session.close()
