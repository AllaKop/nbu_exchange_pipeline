# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path="../.env")
# Out:
# True

# %%
from snowflake.snowpark import Session

connection_parameters = {
    "account": "YUJMLNP-YOB51920",
    "user": os.environ["SNOWFLAKE_USER"],
    "password": os.environ["SNOWFLAKE_PASSWORD"],
    "role": os.environ.get("SNOWFLAKE_ROLE"),
    "warehouse": "COMPUTE_WH",
    "database": "NBU_EXCHANGE",
    "schema": "SILVER"
}

session = Session.builder.configs(connection_parameters).create()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[14], line 13
#       1 from snowflake.snowpark import Session
#       3 connection_parameters = {
#       4     "account": "YUJMLNP-YOB51920",
#       5     "user": os.environ["SNOWFLAKE_USER"],
#    (...)     10     "schema": "SILVER"
#      11 }
# ---> 13 session = Session.builder.configs(connection_parameters).create()
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/snowpark/session.py:526, in Session.SessionBuilder.create(self)
#     524     _add_session(session)
#     525 else:
# --> 526     session = self._create_internal(self._options.get("connection"))
#     528 if self._app_name:
#     529     if self._format_json:
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/snowpark/session.py:568, in Session.SessionBuilder._create_internal(self, conn)
#     565 if "paramstyle" not in self._options:
#     566     self._options["paramstyle"] = "qmark"
#     567 new_session = Session(
# --> 568     ServerConnection({}, conn) if conn else ServerConnection(self._options),
#     569     self._options,
#     570 )
#     572 if "password" in self._options:
#     573     self._options["password"] = None
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/snowpark/_internal/server_connection.py:169, in ServerConnection.__init__(self, options, conn)
#     167 self._lower_case_parameters = {k.lower(): v for k, v in options.items()}
#     168 self._add_application_parameters()
# --> 169 self._conn = conn if conn else connect(**self._lower_case_parameters)
#     170 self.max_string_size = DEFAULT_STRING_SIZE
#     171 if self._conn._session_parameters:
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/connector/__init__.py:64, in Connect(**kwargs)
#      62 @wraps(SnowflakeConnection.__init__)
#      63 def Connect(**kwargs) -> SnowflakeConnection:
# ---> 64     return SnowflakeConnection(**kwargs)
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/connector/connection.py:679, in SnowflakeConnection.__init__(self, connection_name, connections_file_path, **kwargs)
#     677     kwargs = _get_default_connection_params()
#     678 self.__set_error_attributes()
# --> 679 self.connect(**kwargs)
#     680 self._telemetry = TelemetryClient(self._rest)
#     681 self.expired = False
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/connector/connection.py:1174, in SnowflakeConnection.connect(self, **kwargs)
#    1172             raise Exception(str(exceptions_dict))
#    1173 else:
# -> 1174     self.__open_connection()
#    1176 # Register the connection in the pool after successful connection
#    1177 _connections_registry.add_connection(self)
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/connector/connection.py:1602, in SnowflakeConnection.__open_connection(self)
#    1594 else:
#    1595     # okta URL, e.g., https://<account>.okta.com/
#    1596     self.auth_class = AuthByOkta(
#    1597         application=self.application,
#    1598         timeout=self.login_timeout,
#    1599         backoff_generator=self._backoff_generator,
#    1600     )
# -> 1602 self.authenticate_with_retry(self.auth_class)
#    1604 self._password = None  # ensure password won't persist
#    1605 self.auth_class.reset_secrets()
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/connector/connection.py:1938, in SnowflakeConnection.authenticate_with_retry(self, auth_instance)
#    1935 def authenticate_with_retry(self, auth_instance) -> None:
#    1936     # make some changes if needed before real __authenticate
#    1937     try:
# -> 1938         self._authenticate(auth_instance)
#    1939     except ReauthenticationRequest as ex:
#    1940         # cached id_token expiration error, we have cleaned id_token and try to authenticate again
#    1941         logger.debug("ID token expired. Reauthenticating...: %s", ex)
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/connector/connection.py:1970, in SnowflakeConnection._authenticate(self, auth_instance)
#    1968 auth_instance._retry_ctx.set_start_time()
#    1969 try:
# -> 1970     auth.authenticate(
#    1971         auth_instance=auth_instance,
#    1972         account=self.account,
#    1973         user=self.user,
#    1974         database=self.database,
#    1975         schema=self.schema,
#    1976         warehouse=self.warehouse,
#    1977         role=self.role,
#    1978         passcode=self._passcode,
#    1979         passcode_in_password=self._passcode_in_password,
#    1980         mfa_callback=self._mfa_callback,
#    1981         password_callback=self._password_callback,
#    1982         session_parameters=self._session_parameters,
#    1983     )
#    1984 except OperationalError as e:
#    1985     logger.debug(
#    1986         "Operational Error raised at authentication"
#    1987         f"for authenticator: {type(auth_instance).__name__}"
#    1988     )
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/connector/auth/_auth.py:442, in Auth.authenticate(self, auth_instance, account, user, database, schema, warehouse, role, passcode, passcode_in_password, mfa_callback, password_callback, session_parameters, timeout)
#     438     if isinstance(auth_instance, AuthByUsrPwdMfa):
#     439         self._delete_temporary_credential(
#     440             self._rest._host, user, TokenType.MFA_TOKEN
#     441         )
# --> 442     Error.errorhandler_wrapper(
#     443         self._rest._connection,
#     444         None,
#     445         DatabaseError,
#     446         {
#     447             "msg": (
#     448                 "Failed to connect to DB: {host}:{port}. " "{message}"
#     449             ).format(
#     450                 host=self._rest._host,
#     451                 port=self._rest._port,
#     452                 message=ret["message"],
#     453             ),
#     454             "errno": ER_FAILED_TO_CONNECT_TO_DB,
#     455             "sqlstate": SQLSTATE_CONNECTION_WAS_NOT_ESTABLISHED,
#     456         },
#     457     )
#     458 else:
#     459     logger.debug(
#     460         "token = %s",
#     461         (
#    (...)    465         ),
#     466     )
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/connector/errors.py:298, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     275 @staticmethod
#     276 def errorhandler_wrapper(
#     277     connection: SnowflakeConnection | None,
#    (...)    280     error_value: dict[str, Any],
#     281 ) -> None:
#     282     """Error handler wrapper that calls the errorhandler method.
#     283
#     284     Args:
#    (...)    295         exception to the first handler in that order.
#     296     """
# --> 298     handed_over = Error.hand_to_other_handler(
#     299         connection,
#     300         cursor,
#     301         error_class,
#     302         error_value,
#     303     )
#     304     if not handed_over:
#     305         raise Error.errorhandler_make_exception(
#     306             error_class,
#     307             error_value,
#     308         )
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/connector/errors.py:361, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     359 elif connection is not None:
#     360     try:
# --> 361         connection.errorhandler(connection, cursor, error_class, error_value)
#     362     except NotImplementedError:
#     363         # for async compatibility, check SNOW-1763096 and SNOW-1763103
#     364         connection._errorhandler(connection, cursor, error_class, error_value)
#
# File ~/nbu_exchange_pipeline/nbu_exchange_venv/lib/python3.13/site-packages/snowflake/connector/errors.py:229, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     227 errno = error_value.get("errno")
#     228 done_format_msg = error_value.get("done_format_msg")
# --> 229 raise error_class(
#     230     msg=error_value.get("msg"),
#     231     errno=None if errno is None else int(errno),
#     232     sqlstate=error_value.get("sqlstate"),
#     233     sfqid=error_value.get("sfqid"),
#     234     query=error_value.get("query"),
#     235     done_format_msg=(
#     236         None if done_format_msg is None else bool(done_format_msg)
#     237     ),
#     238     connection=connection,
#     239     cursor=cursor,
#     240 )
#
# DatabaseError: 250001 (08001): Failed to connect to DB: YUJMLNP-YOB51920.snowflakecomputing.com:443. Incorrect username or password was specified.

# %%
exchange_rate_extracted_df = session.table("nbu_exchange.silver.exchange_rate_extracted")
exchange_rate_extracted_df.show(5)
# Out:
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"CALCULATION_DATE"  |"CURRENCY_CODE"  |"CURRENCY_NAME"  |"EXCHANGE_DATE"  |"GROUP_NUMBER"  |"R030_CODE"  |"RATE"     |"RATE_PER_UNIT"  |"SPECIAL_CONDITIONS"  |"CURRENCY_NAME_UA"  |"UNITS"  |
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |                    |MDL              |NULL             |30.11.2013       |1               |498          |60.9534    |0.609534         |NULL                  |Молдовський лей     |100      |
# |                    |GEL              |NULL             |30.11.2013       |2               |981          |478.4222   |4.784222         |NULL                  |Ларi                |100      |
# |                    |XPD              |NULL             |30.11.2013       |3               |964          |57389.74   |5738.974         |NULL                  |Паладiй             |10       |
# |                    |XPT              |NULL             |30.11.2013       |3               |962          |108784.73  |10878.473        |NULL                  |Платина             |10       |
# |                    |RUB              |NULL             |30.11.2013       |1               |643          |2.4124     |0.24124          |NULL                  |Російський рубль    |10       |
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# -- Need to do:
# -- 0. deduplicate - after cleaning and mapping!
# -- 3. currency_code upper case maybe
# -- 4. currency_name has nulls (IS null), map
# -- 6. group_number (1,2,3) find what's the meaning, map with names
# -- 7. r030_code - 150 r030 count, 109 currency count?
# -- 8. r030_code - 3d group is precious metals, 2nd and 1st the same currency?
# -- 9. rate - seems ok
# -- 10. rate_per_unit - seems ok
# -- 11. special_conditions - seems ok
# -- Special=null/Y/N - sign of the conditions for calculating the hryvnia to US dollar
# -- exchange rate: null - for records for days when the sign was not determined and for
# -- valcode≠usd, Y - under special conditions, N - under normal conditions;
# -- 12. currency_name_ua - seems ok, can add additional column with countries
# -- 13. units - seems ok
# -- add collumn if records valid
#
# -- Create a new table for cleaned and transformed data

# %%
from snowflake.snowpark.functions import col, when, trim, to_date, lit, sql_expr

# %%
# Cast date columns to date type and handle null or empty values for calculation_date

exchange_rate_extracted_df = exchange_rate_extracted_df \
    .with_column(
        "calculation_date",
        when(
            (trim(col("calculation_date")) == lit('')) | col("calculation_date").is_null(),
            to_date(lit("01.01.1900"), "DD.MM.YYYY")
        ).otherwise(
            to_date(trim(col("calculation_date")), "DD.MM.YYYY")
        )
    ) \
    .with_column(
        "exchange_date",
        to_date(col("exchange_date"), "DD.MM.YYYY")
    )

# %%
exchange_rate_extracted_df \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .order_by('currency_name_ua') \
    .show(250)
# Out:
# --------------------------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"              |"CURRENCY_NAME_UA"                  |
# --------------------------------------------------------------------------------------
# |DEM              |NULL                         |Hімецькі маpки                      |
# |EUR              |NULL                         |Євро                                |
# |EUR              |Euro                         |Євро                                |
# |EGP              |NULL                         |Єгипетський фунт                    |
# |EGP              |Egyptian Pound               |Єгипетський фунт                    |
# |JPY              |NULL                         |Єна                                 |
# |JPY              |Yen                          |Єна                                 |
# |INR              |Indian Rupee                 |Індійська рупія                     |
# |INR              |NULL                         |Індійська рупія                     |
# |IQD              |NULL                         |Іракський динар                     |
# |IQD              |Iraqi Dinar                  |Іракський динар                     |
# |IRR              |Iranian Rial                 |Іранський ріал                      |
# |IRR              |NULL                         |Іранський ріал                      |
# |IEP              |NULL                         |Ірландський фунт                    |
# |IEP              |NULL                         |Ірландські фунти                    |
# |ISK              |NULL                         |Ісландська крона                    |
# |ISK              |NULL                         |Ісландські крони                    |
# |ESP              |NULL                         |Іспанскі пессети                    |
# |ESP              |NULL                         |Іспанська песета                    |
# |ITL              |NULL                         |Італійська ліра                     |
# |ITL              |NULL                         |Італійські ліpи                     |
# |AUD              |Australian Dollar            |Австралійський долар                |
# |AUD              |NULL                         |Австралійський долар                |
# |ATS              |NULL                         |Австрійський шилінг                 |
# |AZN              |NULL                         |Азербайджанський манат              |
# |AZM              |NULL                         |Азербайджанський манат              |
# |AZN              |Azerbaijan Manat             |Азербайджанський манат              |
# |DZD              |NULL                         |Алжирський динар                    |
# |DZD              |Algerian Dinar               |Алжирський динар                    |
# |GBP              |NULL                         |Англійський фунт стерлінгів         |
# |BYB              |NULL                         |Бiлоруський рубль                   |
# |BYN              |Belarusian Ruble             |Бiлоруський рубль                   |
# |BYN              |NULL                         |Бiлоруський рубль                   |
# |BYR              |NULL                         |Бiлоруський рубль                   |
# |THB              |Baht                         |Бат                                 |
# |THB              |NULL                         |Бат                                 |
# |BEF              |NULL                         |Бельгійський франк                  |
# |BGN              |NULL                         |Болгарський лев                     |
# |BGN              |Bulgarian Lev                |Болгарський лев                     |
# |BGL              |NULL                         |Болгарські леви                     |
# |BRL              |NULL                         |Бразильський реал                   |
# |BRL              |Brazilian Real               |Бразильський реал                   |
# |BYN              |Belarusian Ruble             |Білоруський рубль                   |
# |WDR              |NULL                         |Вiрменський драм                    |
# |AMD              |NULL                         |Вiрменський драм                    |
# |KRW              |NULL                         |Вон (Республіка Корея)              |
# |KRW              |NULL                         |Вона                                |
# |KRW              |Won                          |Вона                                |
# |AMD              |Armenian Dram                |Вірменський драм                    |
# |GHS              |Ghana Cedi                   |Ганське седі                        |
# |GHS              |NULL                         |Ганських седі                       |
# |NLG              |NULL                         |Голандські гульдени                 |
# |HKD              |Hong Kong Dollar             |Гонконгівський долар                |
# |HKD              |NULL                         |Гонконгівський долар                |
# |GRD              |NULL                         |Грецька драхма                      |
# |GRD              |NULL                         |Грецькі драхми                      |
# |GEK              |NULL                         |Грузинський купон                   |
# |GEL              |NULL                         |Грузинські ларі                     |
# |DKK              |Danish Krone                 |Данська крона                       |
# |DKK              |NULL                         |Данська крона                       |
# |HRD              |NULL                         |Динар                               |
# |AED              |NULL                         |Дирхам ОАЕ                          |
# |AED              |UAE Dirham                   |Дирхам ОАЕ                          |
# |HKD              |NULL                         |Долар Гонконгу                      |
# |USD              |United States dollar         |Долар США                           |
# |USD              |NULL                         |Долар США                           |
# |USD              |US Dollar                    |Долар США                           |
# |___              |NULL                         |Долари США по розр. з Індією        |
# |DOP              |Dominican Peso               |Домініканське песо                  |
# |VND              |Dong                         |Донг                                |
# |VND              |NULL                         |Донг                                |
# |GRD              |NULL                         |Драхма (Греція)                     |
# |XEU              |NULL                         |ЕКЮ                                 |
# |ECS              |NULL                         |Еквадорський сукре                  |
# |XEU              |NULL                         |Екю                                 |
# |EEK              |NULL                         |Естонська крона                     |
# |PLN              |Zloty                        |Злотий                              |
# |PLZ              |NULL                         |Злотий                              |
# |PLN              |NULL                         |Злотий                              |
# |XAU              |NULL                         |Золото                              |
# |XAU              |Gold                         |Золото                              |
# |XOF              |NULL                         |КФА франк BCEAO                     |
# |KZT              |NULL                         |Казахстанський тенге                |
# |CAD              |NULL                         |Канадський долар                    |
# |CAD              |Canadian Dollar              |Канадський долар                    |
# |CYP              |NULL                         |Кипрский фунт                       |
# |CZK              |NULL                         |Коруна                              |
# |EEK              |NULL                         |Крони Естонії                       |
# |KWD              |NULL                         |Кувейтський динар                   |
# |KWD              |NULL                         |Кувейтські динари                   |
# |HRK              |Kuna                         |Куна                                |
# |HRK              |NULL                         |Куна                                |
# |GEL              |NULL                         |Ларi                                |
# |GEL              |Lari                         |Ларі                                |
# |LVL              |NULL                         |Латвійський лат                     |
# |LVL              |NULL                         |Лати Латвії                         |
# |BGL              |NULL                         |Лев (Болгарія)                      |
# |ROL              |NULL                         |Лей (Румунія)                       |
# |LTL              |NULL                         |Литовський літ                      |
# |LTL              |NULL                         |Литовські лити                      |
# |LBP              |Lebanese Pound               |Ліванський фунт                     |
# |LBP              |NULL                         |Ліванський фунт                     |
# |LYD              |NULL                         |Лівійський динар                    |
# |LYD              |Libyan Dinar                 |Лівійський динар                    |
# |MYR              |NULL                         |Малайзійський ринггіт               |
# |MYR              |Malaysian Ringgit            |Малайзійський ринггіт               |
# |MTL              |NULL                         |Мальтійська ліра                    |
# |MTP              |NULL                         |Мальтійська ліра                    |
# |MTL              |NULL                         |Мальтійські ліри                    |
# |TMM              |NULL                         |Манати Туркменії                    |
# |FIM              |NULL                         |Марка (Фінляндія)                   |
# |MAD              |Moroccan Dirham              |Марокканський дирхам                |
# |MAD              |NULL                         |Марокканський дирхам                |
# |MXN              |Mexican Peso                 |Мексиканське песо                   |
# |MXN              |NULL                         |Мексіканський песо                  |
# |MDL              |NULL                         |Молдовський лей                     |
# |MDL              |Moldovan Leu                 |Молдовський лей                     |
# |MNT              |NULL                         |Монгольский тугрик                  |
# |NLG              |NULL                         |Нiдерландський гульден              |
# |TWD              |New Taiwan Dollar            |Новий тайванський долар             |
# |TWD              |NULL                         |Новий тайванський долар             |
# |ILS              |New Israeli Sheqel           |Новий ізраїльський шекель           |
# |ILS              |NULL                         |Новий ізраїльський шекель           |
# |NZD              |NULL                         |Новозеландський долар               |
# |NZD              |New Zealand Dollar           |Новозеландський долар               |
# |NOK              |NULL                         |Норвезька крона                     |
# |NOK              |Norwegian Krone              |Норвезька крона                     |
# |DEM              |NULL                         |Німецька марка                      |
# |PKR              |NULL                         |Пакистанська рупія                  |
# |PKR              |Pakistan Rupee               |Пакистанська рупія                  |
# |XPD              |Palladium                    |Паладiй                             |
# |XPD              |NULL                         |Паладiй                             |
# |XPD              |Palladium                    |Паладій                             |
# |PEN              |NULL                         |Перуанский соль                     |
# |XPT              |NULL                         |Платина                             |
# |XPT              |Platinum                     |Платина                             |
# |PTE              |NULL                         |Португальський ескудо               |
# |PTE              |NULL                         |Португальські ескудо                |
# |KPW              |NULL                         |Північнокрейський вон               |
# |ZAR              |Rand                         |Ренд                                |
# |ZAR              |NULL                         |Ренд                                |
# |RUB              |NULL                         |Російський рубль                    |
# |RUR              |NULL                         |Російський рубль                    |
# |RUB              |Russian Ruble                |Російський рубль                    |
# |RUR              |NULL                         |Російські рублі                     |
# |RON              |NULL                         |Румунський лей                      |
# |RON              |Romanian Leu                 |Румунський лей                      |
# |ROL              |NULL                         |Румунський лей                      |
# |IDR              |NULL                         |Рупія                               |
# |IDR              |Rupiah                       |Рупія                               |
# |XDR              |SDR (Special Drawing Right)  |СПЗ (спеціальні права запозичення)  |
# |XDR              |NULL                         |СПЗ(спец.права запозичення)         |
# |XDR              |NULL                         |СПЗ(спеціальні права запозичення)   |
# |SAR              |NULL                         |Саудівський рiал                    |
# |SAR              |NULL                         |Саудівський рiял                    |
# |SAR              |Saudi Riyal                  |Саудівський рiял                    |
# |SAR              |Saudi Riyal                  |Саудівський ріял                    |
# |RSD              |Serbian Dinar                |Сербський динар                     |
# |RSD              |NULL                         |Сербський динар                     |
# |SYP              |NULL                         |Сирійский фунт                      |
# |SKK              |NULL                         |Словацька крона                     |
# |SKK              |NULL                         |Словацькі крони                     |
# |SIT              |NULL                         |Словенський толар                   |
# |SIT              |NULL                         |Словенські толари                   |
# |KGS              |Som                          |Сом                                 |
# |KGS              |NULL                         |Сом                                 |
# |KGS              |NULL                         |Сом (Киргизстан)                    |
# |TJS              |NULL                         |Сомонi                              |
# |TJS              |Somoni                       |Сомоні                              |
# |SDR              |NULL                         |Спецiальнi права запозичення        |
# |XDR              |NULL                         |Спецiальнi права запозичення        |
# |XAG              |NULL                         |Срiбло                              |
# |XAG              |Silver                       |Срiбло                              |
# |XAG              |Silver                       |Срібло                              |
# |SGD              |Singapore Dollar             |Сінгапурський долар                 |
# |SGD              |NULL                         |Сінгапурський долар                 |
# |TJS              |NULL                         |Таджикистанський сомоні             |
# |BDT              |NULL                         |Така                                |
# |BDT              |Taka                         |Така                                |
# |KZT              |Tenge                        |Теньге                              |
# |KZT              |NULL                         |Теньге                              |
# |SIT              |NULL                         |Толар (Словенія)                    |
# |TND              |Tunisian Dinar               |Туніський динар                     |
# |TND              |NULL                         |Туніський динар                     |
# |TRL              |NULL                         |Турецька ліра                       |
# |TRY              |Turkish Lira                 |Турецька ліра                       |
# |TRY              |NULL                         |Турецька ліра                       |
# |TRL              |NULL                         |Турецькі ліри                       |
# |TMM              |NULL                         |Туркменський манат                  |
# |TMT              |NULL                         |Туркменський манат                  |
# |TMT              |Turkmenistan New Manat       |Туркменський новий  манат           |
# |TMT              |Turkmenistan New Manat       |Туркменський новий манат            |
# |TMT              |NULL                         |Туркменський новий манат            |
# |UZS              |Uzbekistan Som               |Узбецький сум                       |
# |USM              |NULL                         |Узбецький сум                       |
# |UZS              |NULL                         |Узбецький сум                       |
# |UZS              |Uzbekistan Sum               |Узбецький сум                       |
# |FRF              |NULL                         |Фpанцузський фpанк                  |
# |HUF              |NULL                         |Форинт                              |
# |HUF              |Forint                       |Форинт                              |
# |HUF              |NULL                         |Форинт (Угорщина)                   |
# |XOF              |NULL                         |Франки CFA-BCEAO                    |
# |FRF              |NULL                         |Французький франк                   |
# |GBP              |NULL                         |Фунт стерлінгів                     |
# |GBP              |Pound Sterling               |Фунт стерлінгів                     |
# |PHP              |Philippine Piso              |Філіппінське песо                   |
# |ZAL              |NULL                         |Фінансовий ренд ПАР                 |
# |FIM              |NULL                         |Фінські маpки                       |
# |HRK              |NULL                         |Хорватська куна                     |
# |CZK              |Czech Koruna                 |Чеська крона                        |
# |CZK              |NULL                         |Чеська крона                        |
# |CLP              |NULL                         |Чілійські песо                      |
# |SEK              |Swedish Krona                |Шведська крона                      |
# |SEK              |NULL                         |Шведська крона                      |
# |CHF              |NULL                         |Швейцарський франк                  |
# |CHF              |Swiss Franc                  |Швейцарський франк                  |
# |ATS              |NULL                         |Шилінг (Австрія)                    |
# |CNY              |NULL                         |Юань Женьмiньбi                     |
# |CNY              |Yuan Renminbi                |Юань Женьмiньбi                     |
# |CNY              |Yuan Renminbi                |Юань Женьміньбі                     |
# |ROL              |NULL                         |новий румунські леї                 |
# --------------------------------------------------------------------------------------

# %%
exchange_rate_extracted_df \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .order_by('currency_name_ua') \
    .count()

# 221
# Out:
# 221

# %%
exchange_rate_extracted_df \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .where(col("currency_name").isNull()) \
    .show(150)
# Out:
# -------------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"  |"CURRENCY_NAME_UA"                 |
# -------------------------------------------------------------------------
# |ROL              |NULL             |Лей (Румунія)                      |
# |EEK              |NULL             |Естонська крона                    |
# |SKK              |NULL             |Словацька крона                    |
# |SIT              |NULL             |Толар (Словенія)                   |
# |SDR              |NULL             |Спецiальнi права запозичення       |
# |ROL              |NULL             |Румунський лей                     |
# |ITL              |NULL             |Італійська ліра                    |
# |XDR              |NULL             |Спецiальнi права запозичення       |
# |NLG              |NULL             |Нiдерландський гульден             |
# |KWD              |NULL             |Кувейтський динар                  |
# |ISK              |NULL             |Ісландська крона                   |
# |IEP              |NULL             |Ірландський фунт                   |
# |WDR              |NULL             |Вiрменський драм                   |
# |HRK              |NULL             |Хорватська куна                    |
# |GEK              |NULL             |Грузинський купон                  |
# |RUR              |NULL             |Російський рубль                   |
# |TRL              |NULL             |Турецька ліра                      |
# |XEU              |NULL             |Екю                                |
# |GRD              |NULL             |Драхма (Греція)                    |
# |XDR              |NULL             |СПЗ(спеціальні права запозичення)  |
# |HUF              |NULL             |Форинт (Угорщина)                  |
# |KGS              |NULL             |Сом (Киргизстан)                   |
# |PTE              |NULL             |Португальський ескудо              |
# |KZT              |NULL             |Казахстанський тенге               |
# |MDL              |NULL             |Молдовський лей                    |
# |GEL              |NULL             |Ларi                               |
# |XPD              |NULL             |Паладiй                            |
# |XPT              |NULL             |Платина                            |
# |RUB              |NULL             |Російський рубль                   |
# |XDR              |NULL             |СПЗ(спец.права запозичення)        |
# |HUF              |NULL             |Форинт                             |
# |GBP              |NULL             |Фунт стерлінгів                    |
# |CZK              |NULL             |Чеська крона                       |
# |CNY              |NULL             |Юань Женьмiньбi                    |
# |HKD              |NULL             |Гонконгівський долар               |
# |AMD              |NULL             |Вiрменський драм                   |
# |DKK              |NULL             |Данська крона                      |
# |LVL              |NULL             |Лати Латвії                        |
# |NZD              |NULL             |Новозеландський долар              |
# |PKR              |NULL             |Пакистанська рупія                 |
# |SYP              |NULL             |Сирійский фунт                     |
# |XOF              |NULL             |Франки CFA-BCEAO                   |
# |___              |NULL             |Долари США по розр. з Індією       |
# |VND              |NULL             |Донг                               |
# |BGL              |NULL             |Болгарські леви                    |
# |AZM              |NULL             |Азербайджанський манат             |
# |BYR              |NULL             |Бiлоруський рубль                  |
# |TRL              |NULL             |Турецькі ліри                      |
# |KRW              |NULL             |Вона                               |
# |SAR              |NULL             |Саудівський рiял                   |
# |BGN              |NULL             |Болгарський лев                    |
# |RON              |NULL             |Румунський лей                     |
# |SKK              |NULL             |Словацькі крони                    |
# |ESP              |NULL             |Іспанскі пессети                   |
# |ECS              |NULL             |Еквадорський сукре                 |
# |MTL              |NULL             |Мальтійські ліри                   |
# |CHF              |NULL             |Швейцарський франк                 |
# |JPY              |NULL             |Єна                                |
# |NOK              |NULL             |Норвезька крона                    |
# |KZT              |NULL             |Теньге                             |
# |AZN              |NULL             |Азербайджанський манат             |
# |ATS              |NULL             |Австрійський шилінг                |
# |FRF              |NULL             |Фpанцузський фpанк                 |
# |GRD              |NULL             |Грецькі драхми                     |
# |IEP              |NULL             |Ірландські фунти                   |
# |ITL              |NULL             |Італійські ліpи                    |
# |PTE              |NULL             |Португальські ескудо               |
# |BYB              |NULL             |Бiлоруський рубль                  |
# |GEL              |NULL             |Грузинські ларі                    |
# |IDR              |NULL             |Рупія                              |
# |BDT              |NULL             |Така                               |
# |TMT              |NULL             |Туркменський новий манат           |
# |TJS              |NULL             |Таджикистанський сомоні            |
# |TMM              |NULL             |Туркменський манат                 |
# |GRD              |NULL             |Грецька драхма                     |
# |SIT              |NULL             |Словенський толар                  |
# |XEU              |NULL             |ЕКЮ                                |
# |MTP              |NULL             |Мальтійська ліра                   |
# |PLZ              |NULL             |Злотий                             |
# |CZK              |NULL             |Коруна                             |
# |HKD              |NULL             |Долар Гонконгу                     |
# |BGL              |NULL             |Лев (Болгарія)                     |
# |FRF              |NULL             |Французький франк                  |
# |USM              |NULL             |Узбецький сум                      |
# |MTL              |NULL             |Мальтійська ліра                   |
# |ATS              |NULL             |Шилінг (Австрія)                   |
# |GHS              |NULL             |Ганських седі                      |
# |LVL              |NULL             |Латвійський лат                    |
# |DEM              |NULL             |Німецька марка                     |
# |ESP              |NULL             |Іспанська песета                   |
# |FIM              |NULL             |Марка (Фінляндія)                  |
# |TMT              |NULL             |Туркменський манат                 |
# |ZAL              |NULL             |Фінансовий ренд ПАР                |
# |KRW              |NULL             |Вон (Республіка Корея)             |
# |HRD              |NULL             |Динар                              |
# |XOF              |NULL             |КФА франк BCEAO                    |
# |LTL              |NULL             |Литовський літ                     |
# |GBP              |NULL             |Англійський фунт стерлінгів        |
# |SAR              |NULL             |Саудівський рiал                   |
# |SGD              |NULL             |Сінгапурський долар                |
# |XAG              |NULL             |Срiбло                             |
# |SEK              |NULL             |Шведська крона                     |
# |IQD              |NULL             |Іракський динар                    |
# |IRR              |NULL             |Іранський ріал                     |
# |USD              |NULL             |Долар США                          |
# |EUR              |NULL             |Євро                               |
# |ISK              |NULL             |Ісландські крони                   |
# |CAD              |NULL             |Канадський долар                   |
# |EGP              |NULL             |Єгипетський фунт                   |
# |KWD              |NULL             |Кувейтські динари                  |
# |LBP              |NULL             |Ліванський фунт                    |
# |MNT              |NULL             |Монгольский тугрик                 |
# |PEN              |NULL             |Перуанский соль                    |
# |UZS              |NULL             |Узбецький сум                      |
# |AUD              |NULL             |Австралійський долар               |
# |XAU              |NULL             |Золото                             |
# |LTL              |NULL             |Литовські лити                     |
# |ROL              |NULL             |новий румунські леї                |
# |CLP              |NULL             |Чілійські песо                     |
# |PLN              |NULL             |Злотий                             |
# |TMM              |NULL             |Манати Туркменії                   |
# |MXN              |NULL             |Мексіканський песо                 |
# |BEF              |NULL             |Бельгійський франк                 |
# |EEK              |NULL             |Крони Естонії                      |
# |NLG              |NULL             |Голандські гульдени                |
# |RUR              |NULL             |Російські рублі                    |
# |KPW              |NULL             |Північнокрейський вон              |
# |AED              |NULL             |Дирхам ОАЕ                         |
# |MYR              |NULL             |Малайзійський ринггіт              |
# |TND              |NULL             |Туніський динар                    |
# |MAD              |NULL             |Марокканський дирхам               |
# |ZAR              |NULL             |Ренд                               |
# |HRK              |NULL             |Куна                               |
# |ILS              |NULL             |Новий ізраїльський шекель          |
# |TWD              |NULL             |Новий тайванський долар            |
# |BRL              |NULL             |Бразильський реал                  |
# |INR              |NULL             |Індійська рупія                    |
# |KGS              |NULL             |Сом                                |
# |TJS              |NULL             |Сомонi                             |
# |LYD              |NULL             |Лівійський динар                   |
# |TRY              |NULL             |Турецька ліра                      |
# |FIM              |NULL             |Фінські маpки                      |
# |DEM              |NULL             |Hімецькі маpки                     |
# |SIT              |NULL             |Словенські толари                  |
# |BYN              |NULL             |Бiлоруський рубль                  |
# |THB              |NULL             |Бат                                |
# |DZD              |NULL             |Алжирський динар                   |
# |CYP              |NULL             |Кипрский фунт                      |
# |RSD              |NULL             |Сербський динар                    |
# -------------------------------------------------------------------------

# %%
exchange_rate_extracted_df \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .where(col("currency_name").isNull()) \
    .count()

# 149
# Out:
# 149

# %%
exchange_rate_extracted_df \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .where(col("currency_code") == "AUD") \
    .order_by(col("currency_name").desc()) \
    .show(10)
# Out:
# --------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"    |"CURRENCY_NAME_UA"    |
# --------------------------------------------------------------
# |AUD              |Australian Dollar  |Австралійський долар  |
# |AUD              |NULL               |Австралійський долар  |
# --------------------------------------------------------------

# %%
from snowflake.snowpark import Window
from snowflake.snowpark.functions import coalesce, first_value, trim, upper

# To fill in nulls in currency_name with value from currency_name that has the same code

windows = Window.partition_by(trim(upper(col("currency_code")))).order_by(col("currency_name").desc())

exchange_rate_extracted_df_m = exchange_rate_extracted_df \
    .with_column(
        "currency_name",
        coalesce(
            col("currency_name"),
            first_value(col("currency_name")).over(windows)
        )
    )

# %%
exchange_rate_extracted_df_m \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .order_by('currency_name_ua') \
    .count()

# 165
# Out:
# 165

# %%
exchange_rate_extracted_df_m \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .order_by('currency_name_ua') \
    .show(170)
# Out:
# --------------------------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"              |"CURRENCY_NAME_UA"                  |
# --------------------------------------------------------------------------------------
# |DEM              |NULL                         |Hімецькі маpки                      |
# |EUR              |Euro                         |Євро                                |
# |EGP              |Egyptian Pound               |Єгипетський фунт                    |
# |JPY              |Yen                          |Єна                                 |
# |INR              |Indian Rupee                 |Індійська рупія                     |
# |IQD              |Iraqi Dinar                  |Іракський динар                     |
# |IRR              |Iranian Rial                 |Іранський ріал                      |
# |IEP              |NULL                         |Ірландський фунт                    |
# |IEP              |NULL                         |Ірландські фунти                    |
# |ISK              |NULL                         |Ісландська крона                    |
# |ISK              |NULL                         |Ісландські крони                    |
# |ESP              |NULL                         |Іспанскі пессети                    |
# |ESP              |NULL                         |Іспанська песета                    |
# |ITL              |NULL                         |Італійська ліра                     |
# |ITL              |NULL                         |Італійські ліpи                     |
# |AUD              |Australian Dollar            |Австралійський долар                |
# |ATS              |NULL                         |Австрійський шилінг                 |
# |AZN              |Azerbaijan Manat             |Азербайджанський манат              |
# |AZM              |NULL                         |Азербайджанський манат              |
# |DZD              |Algerian Dinar               |Алжирський динар                    |
# |GBP              |Pound Sterling               |Англійський фунт стерлінгів         |
# |BYB              |NULL                         |Бiлоруський рубль                   |
# |BYN              |Belarusian Ruble             |Бiлоруський рубль                   |
# |BYR              |NULL                         |Бiлоруський рубль                   |
# |THB              |Baht                         |Бат                                 |
# |BEF              |NULL                         |Бельгійський франк                  |
# |BGN              |Bulgarian Lev                |Болгарський лев                     |
# |BGL              |NULL                         |Болгарські леви                     |
# |BRL              |Brazilian Real               |Бразильський реал                   |
# |BYN              |Belarusian Ruble             |Білоруський рубль                   |
# |WDR              |NULL                         |Вiрменський драм                    |
# |AMD              |Armenian Dram                |Вiрменський драм                    |
# |KRW              |Won                          |Вон (Республіка Корея)              |
# |KRW              |Won                          |Вона                                |
# |AMD              |Armenian Dram                |Вірменський драм                    |
# |GHS              |Ghana Cedi                   |Ганське седі                        |
# |GHS              |Ghana Cedi                   |Ганських седі                       |
# |NLG              |NULL                         |Голандські гульдени                 |
# |HKD              |Hong Kong Dollar             |Гонконгівський долар                |
# |GRD              |NULL                         |Грецька драхма                      |
# |GRD              |NULL                         |Грецькі драхми                      |
# |GEK              |NULL                         |Грузинський купон                   |
# |GEL              |Lari                         |Грузинські ларі                     |
# |DKK              |Danish Krone                 |Данська крона                       |
# |HRD              |NULL                         |Динар                               |
# |AED              |UAE Dirham                   |Дирхам ОАЕ                          |
# |HKD              |Hong Kong Dollar             |Долар Гонконгу                      |
# |USD              |United States dollar         |Долар США                           |
# |USD              |US Dollar                    |Долар США                           |
# |___              |NULL                         |Долари США по розр. з Індією        |
# |DOP              |Dominican Peso               |Домініканське песо                  |
# |VND              |Dong                         |Донг                                |
# |GRD              |NULL                         |Драхма (Греція)                     |
# |XEU              |NULL                         |ЕКЮ                                 |
# |ECS              |NULL                         |Еквадорський сукре                  |
# |XEU              |NULL                         |Екю                                 |
# |EEK              |NULL                         |Естонська крона                     |
# |PLN              |Zloty                        |Злотий                              |
# |PLZ              |NULL                         |Злотий                              |
# |XAU              |Gold                         |Золото                              |
# |XOF              |NULL                         |КФА франк BCEAO                     |
# |KZT              |Tenge                        |Казахстанський тенге                |
# |CAD              |Canadian Dollar              |Канадський долар                    |
# |CYP              |NULL                         |Кипрский фунт                       |
# |CZK              |Czech Koruna                 |Коруна                              |
# |EEK              |NULL                         |Крони Естонії                       |
# |KWD              |NULL                         |Кувейтський динар                   |
# |KWD              |NULL                         |Кувейтські динари                   |
# |HRK              |Kuna                         |Куна                                |
# |GEL              |Lari                         |Ларi                                |
# |GEL              |Lari                         |Ларі                                |
# |LVL              |NULL                         |Латвійський лат                     |
# |LVL              |NULL                         |Лати Латвії                         |
# |BGL              |NULL                         |Лев (Болгарія)                      |
# |ROL              |NULL                         |Лей (Румунія)                       |
# |LTL              |NULL                         |Литовський літ                      |
# |LTL              |NULL                         |Литовські лити                      |
# |LBP              |Lebanese Pound               |Ліванський фунт                     |
# |LYD              |Libyan Dinar                 |Лівійський динар                    |
# |MYR              |Malaysian Ringgit            |Малайзійський ринггіт               |
# |MTL              |NULL                         |Мальтійська ліра                    |
# |MTP              |NULL                         |Мальтійська ліра                    |
# |MTL              |NULL                         |Мальтійські ліри                    |
# |TMM              |NULL                         |Манати Туркменії                    |
# |FIM              |NULL                         |Марка (Фінляндія)                   |
# |MAD              |Moroccan Dirham              |Марокканський дирхам                |
# |MXN              |Mexican Peso                 |Мексиканське песо                   |
# |MXN              |Mexican Peso                 |Мексіканський песо                  |
# |MDL              |Moldovan Leu                 |Молдовський лей                     |
# |MNT              |NULL                         |Монгольский тугрик                  |
# |NLG              |NULL                         |Нiдерландський гульден              |
# |TWD              |New Taiwan Dollar            |Новий тайванський долар             |
# |ILS              |New Israeli Sheqel           |Новий ізраїльський шекель           |
# |NZD              |New Zealand Dollar           |Новозеландський долар               |
# |NOK              |Norwegian Krone              |Норвезька крона                     |
# |DEM              |NULL                         |Німецька марка                      |
# |PKR              |Pakistan Rupee               |Пакистанська рупія                  |
# |XPD              |Palladium                    |Паладiй                             |
# |XPD              |Palladium                    |Паладій                             |
# |PEN              |NULL                         |Перуанский соль                     |
# |XPT              |Platinum                     |Платина                             |
# |PTE              |NULL                         |Португальський ескудо               |
# |PTE              |NULL                         |Португальські ескудо                |
# |KPW              |NULL                         |Північнокрейський вон               |
# |ZAR              |Rand                         |Ренд                                |
# |RUR              |NULL                         |Російський рубль                    |
# |RUB              |Russian Ruble                |Російський рубль                    |
# |RUR              |NULL                         |Російські рублі                     |
# |ROL              |NULL                         |Румунський лей                      |
# |RON              |Romanian Leu                 |Румунський лей                      |
# |IDR              |Rupiah                       |Рупія                               |
# |XDR              |SDR (Special Drawing Right)  |СПЗ (спеціальні права запозичення)  |
# |XDR              |SDR (Special Drawing Right)  |СПЗ(спец.права запозичення)         |
# |XDR              |SDR (Special Drawing Right)  |СПЗ(спеціальні права запозичення)   |
# |SAR              |Saudi Riyal                  |Саудівський рiал                    |
# |SAR              |Saudi Riyal                  |Саудівський рiял                    |
# |SAR              |Saudi Riyal                  |Саудівський ріял                    |
# |RSD              |Serbian Dinar                |Сербський динар                     |
# |SYP              |NULL                         |Сирійский фунт                      |
# |SKK              |NULL                         |Словацька крона                     |
# |SKK              |NULL                         |Словацькі крони                     |
# |SIT              |NULL                         |Словенський толар                   |
# |SIT              |NULL                         |Словенські толари                   |
# |KGS              |Som                          |Сом                                 |
# |KGS              |Som                          |Сом (Киргизстан)                    |
# |TJS              |Somoni                       |Сомонi                              |
# |TJS              |Somoni                       |Сомоні                              |
# |XDR              |SDR (Special Drawing Right)  |Спецiальнi права запозичення        |
# |SDR              |NULL                         |Спецiальнi права запозичення        |
# |XAG              |Silver                       |Срiбло                              |
# |XAG              |Silver                       |Срібло                              |
# |SGD              |Singapore Dollar             |Сінгапурський долар                 |
# |TJS              |Somoni                       |Таджикистанський сомоні             |
# |BDT              |Taka                         |Така                                |
# |KZT              |Tenge                        |Теньге                              |
# |SIT              |NULL                         |Толар (Словенія)                    |
# |TND              |Tunisian Dinar               |Туніський динар                     |
# |TRL              |NULL                         |Турецька ліра                       |
# |TRY              |Turkish Lira                 |Турецька ліра                       |
# |TRL              |NULL                         |Турецькі ліри                       |
# |TMT              |Turkmenistan New Manat       |Туркменський манат                  |
# |TMM              |NULL                         |Туркменський манат                  |
# |TMT              |Turkmenistan New Manat       |Туркменський новий  манат           |
# |TMT              |Turkmenistan New Manat       |Туркменський новий манат            |
# |UZS              |Uzbekistan Sum               |Узбецький сум                       |
# |UZS              |Uzbekistan Som               |Узбецький сум                       |
# |USM              |NULL                         |Узбецький сум                       |
# |FRF              |NULL                         |Фpанцузський фpанк                  |
# |HUF              |Forint                       |Форинт                              |
# |HUF              |Forint                       |Форинт (Угорщина)                   |
# |XOF              |NULL                         |Франки CFA-BCEAO                    |
# |FRF              |NULL                         |Французький франк                   |
# |GBP              |Pound Sterling               |Фунт стерлінгів                     |
# |PHP              |Philippine Piso              |Філіппінське песо                   |
# |ZAL              |NULL                         |Фінансовий ренд ПАР                 |
# |FIM              |NULL                         |Фінські маpки                       |
# |HRK              |Kuna                         |Хорватська куна                     |
# |CZK              |Czech Koruna                 |Чеська крона                        |
# |CLP              |NULL                         |Чілійські песо                      |
# |SEK              |Swedish Krona                |Шведська крона                      |
# |CHF              |Swiss Franc                  |Швейцарський франк                  |
# |ATS              |NULL                         |Шилінг (Австрія)                    |
# |CNY              |Yuan Renminbi                |Юань Женьмiньбi                     |
# |CNY              |Yuan Renminbi                |Юань Женьміньбі                     |
# |ROL              |NULL                         |новий румунські леї                 |
# --------------------------------------------------------------------------------------

# %%
exchange_rate_extracted_df_m \
    .select('currency_code', 'currency_name', 'currency_name_ua') \
    .distinct() \
    .where(col("currency_name").isNull()) \
    .order_by('currency_name_ua') \
    .show(80)
# Out:
# --------------------------------------------------------------------
# |"CURRENCY_CODE"  |"CURRENCY_NAME"  |"CURRENCY_NAME_UA"            |
# --------------------------------------------------------------------
# |DEM              |NULL             |Hімецькі маpки                |
# |IEP              |NULL             |Ірландський фунт              |
# |IEP              |NULL             |Ірландські фунти              |
# |ISK              |NULL             |Ісландська крона              |
# |ISK              |NULL             |Ісландські крони              |
# |ESP              |NULL             |Іспанскі пессети              |
# |ESP              |NULL             |Іспанська песета              |
# |ITL              |NULL             |Італійська ліра               |
# |ITL              |NULL             |Італійські ліpи               |
# |ATS              |NULL             |Австрійський шилінг           |
# |AZM              |NULL             |Азербайджанський манат        |
# |BYR              |NULL             |Бiлоруський рубль             |
# |BYB              |NULL             |Бiлоруський рубль             |
# |BEF              |NULL             |Бельгійський франк            |
# |BGL              |NULL             |Болгарські леви               |
# |WDR              |NULL             |Вiрменський драм              |
# |NLG              |NULL             |Голандські гульдени           |
# |GRD              |NULL             |Грецька драхма                |
# |GRD              |NULL             |Грецькі драхми                |
# |GEK              |NULL             |Грузинський купон             |
# |HRD              |NULL             |Динар                         |
# |___              |NULL             |Долари США по розр. з Індією  |
# |GRD              |NULL             |Драхма (Греція)               |
# |XEU              |NULL             |ЕКЮ                           |
# |ECS              |NULL             |Еквадорський сукре            |
# |XEU              |NULL             |Екю                           |
# |EEK              |NULL             |Естонська крона               |
# |PLZ              |NULL             |Злотий                        |
# |XOF              |NULL             |КФА франк BCEAO               |
# |CYP              |NULL             |Кипрский фунт                 |
# |EEK              |NULL             |Крони Естонії                 |
# |KWD              |NULL             |Кувейтський динар             |
# |KWD              |NULL             |Кувейтські динари             |
# |LVL              |NULL             |Латвійський лат               |
# |LVL              |NULL             |Лати Латвії                   |
# |BGL              |NULL             |Лев (Болгарія)                |
# |ROL              |NULL             |Лей (Румунія)                 |
# |LTL              |NULL             |Литовський літ                |
# |LTL              |NULL             |Литовські лити                |
# |MTL              |NULL             |Мальтійська ліра              |
# |MTP              |NULL             |Мальтійська ліра              |
# |MTL              |NULL             |Мальтійські ліри              |
# |TMM              |NULL             |Манати Туркменії              |
# |FIM              |NULL             |Марка (Фінляндія)             |
# |MNT              |NULL             |Монгольский тугрик            |
# |NLG              |NULL             |Нiдерландський гульден        |
# |DEM              |NULL             |Німецька марка                |
# |PEN              |NULL             |Перуанский соль               |
# |PTE              |NULL             |Португальський ескудо         |
# |PTE              |NULL             |Португальські ескудо          |
# |KPW              |NULL             |Північнокрейський вон         |
# |RUR              |NULL             |Російський рубль              |
# |RUR              |NULL             |Російські рублі               |
# |ROL              |NULL             |Румунський лей                |
# |SYP              |NULL             |Сирійский фунт                |
# |SKK              |NULL             |Словацька крона               |
# |SKK              |NULL             |Словацькі крони               |
# |SIT              |NULL             |Словенський толар             |
# |SIT              |NULL             |Словенські толари             |
# |SDR              |NULL             |Спецiальнi права запозичення  |
# |SIT              |NULL             |Толар (Словенія)              |
# |TRL              |NULL             |Турецька ліра                 |
# |TRL              |NULL             |Турецькі ліри                 |
# |TMM              |NULL             |Туркменський манат            |
# |USM              |NULL             |Узбецький сум                 |
# |FRF              |NULL             |Фpанцузський фpанк            |
# |XOF              |NULL             |Франки CFA-BCEAO              |
# |FRF              |NULL             |Французький франк             |
# |ZAL              |NULL             |Фінансовий ренд ПАР           |
# |FIM              |NULL             |Фінські маpки                 |
# |CLP              |NULL             |Чілійські песо                |
# |ATS              |NULL             |Шилінг (Австрія)              |
# |ROL              |NULL             |новий румунські леї           |
# --------------------------------------------------------------------

# %%
# ! Upload static file with mapping of currency codes to names 
# and join with existing data to fill in missing values.

# check all codes vs file

# %%
select distinct currency_code, currency_name, currency_name_ua, r030_code
from nbu_exchange.silver.exchange_rate_extracted
where currency_name is null
order by currency_code;

select distinct currency_code, currency_name, currency_name_ua, r030_code
from nbu_exchange.silver.exchange_rate_extracted
where currency_name is null
order by r030_code, currency_code;

select distinct currency_code, currency_name, currency_name_ua, r030_code
from nbu_exchange.silver.exchange_rate_extracted
where currency_code = 'SDR' or currency_code = 'XDR' or r030_code = 960
;
# Out:
#   Cell In[75], line 1
#     select distinct currency_code, currency_name
#            ^
# SyntaxError: invalid syntax

# %%
# session.close()
